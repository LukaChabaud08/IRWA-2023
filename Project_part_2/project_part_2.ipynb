# %% [markdown]
# # Part 2: Indexing and Evaluation

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Imports
from collections import defaultdict
from array import array
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import math
import numpy as np
import collections
from numpy import linalg as la
import json
import re
import pandas as pd
import string
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import spacy


nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import json
import csv


#Path of the resulting JSON file of part 1
docs_path = '/content/drive/Shareddrives/IRWA/IRWA_data_2023/Rus_Ukr_war_data_clean.json'
csv_path = '/content/drive/Shareddrives/IRWA/IRWA_data_2023/Rus_Ukr_war_data_ids.csv'

doc_ids = []

#First we will load the data
with open(csv_path, newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter='\t')
    for row in reader:
        doc_id = row[0]
        doc_ids.append(doc_id)

#Next we will load the ids into a map
with open(docs_path) as doc_fp:
    tweets = [json.loads(line) for line in doc_fp.readlines()]

#Get the tweet IDs for all tweets
for tweet, doc_id in zip(tweets, doc_ids):
    tweet['id'] = doc_id

tweets[430]
# Out:
# {'full_text_tokenized': ['artilleri',
#   'ukrain',
#   '#russian',
#   '#russia',
#   '#ukrain',
#   '#ukrainian',
#   '#ukrainewar',
#   '#ukrainerussiawar',
#   '#russiaisaterroristst',
#   'https//tco/oyvpwjcxz'],
#  'created_at': 1664548988000,
#  'hashtags': ['Russians',
#   'Russia',
#   'Ukraine',
#   'Ukrainian',
#   'UkraineWar',
#   'UkraineRussiaWar',
#   'RussiaIsATerroristState'],
#  'favorite_count': 26,
#  'retweet_count': 4,
#  'url': 'https://twitter.com/infussambas/status/1575858789647286272',
#  'id': 'doc_431'}

# %% [markdown]
# ## Indexing

# %% [markdown]
# ### Creating the index

# %%
def create_index(tweets):
    """
    Implement the inverted index

    Argument:
    tweets -- collection of tweets

    Returns:
    index - the inverted index (implemented through a Python dictionary) containing terms as keys and the corresponding
    list of documents where these keys appears in (and the positions) as values.
    """
    index = defaultdict(list)

    for idx, tweet in enumerate(tweets):
        tweet_id = idx+1 #calculate tweet_id
        terms = tweet["full_text_tokenized"] #get full tokenized text of the tweet

        current_page_index = {} #create a dictionary

        #loop through all terms in tokenized text
        for position, term in enumerate(terms):
            try:
                # if the term is already in the index for the current page (current_page_index)
                # append the position to the corresponding list

                current_page_index[term][1].append(position)
            except:
                # Add the new term as dict key and initialize the array of positions and add the position
                current_page_index[term]=[tweet_id, array('I',[position])] #'I' indicates unsigned int (int in Python)

        #merge the current page index with the main index
        for term_page, posting_page in current_page_index.items():
            index[term_page].append(posting_page)


    return index

# %%
import time
#Create indexes for the tweets
start_time = time.time()
index = create_index(tweets)
print("Total time to create the index: {} seconds".format(np.round(time.time() - start_time, 2)))
# Out:
# Total time to create the index: 0.3 seconds

# %%
#Find positions in the documents where the term 'fascist' appears
print("Index results for the term 'fascist': {}\n".format(index['fascist']))
print("First 10 Index results for the term 'fascist': \n{}".format(index['fascist'][:10]))
# Out:
# Index results for the term 'fascist': [[1, array('I', [4])], [136, array('I', [7])], [230, array('I', [3])], [240, array('I', [11])], [413, array('I', [1])], [437, array('I', [7])], [2403, array('I', [4])], [2954, array('I', [1])], [3853, array('I', [4])]]
#
# First 10 Index results for the term 'fascist':
# [[1, array('I', [4])], [136, array('I', [7])], [230, array('I', [3])], [240, array('I', [11])], [413, array('I', [1])], [437, array('I', [7])], [2403, array('I', [4])], [2954, array('I', [1])], [3853, array('I', [4])]]

# %% [markdown]
# ### Querying

# %%
def remove_emojis(text):
    """
    Remove all emojis from the given text

    Argument:
    text -- the text to clean

    Returns:
    text - the same text without emojis
    """

    #All emojis are represented in Unicode, so we can remove them by using RE
    #Regular expression found at https://gist.github.com/slowkow/7a7f61f495e3dbb7e3d767f97bd7304b
    emojis_expression = re.compile("["
                            u"\U0001F600-\U0001F64F"  # emoticons
                            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                            u"\U0001F680-\U0001F6FF"  # transport & map symbols
                            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                            u"\U00002500-\U00002BEF"  # chinese char
                            u"\U00002702-\U000027B0"
                            u"\U00002702-\U000027B0"
                            u"\U000024C2-\U0001F251"
                            u"\U0001f926-\U0001f937"
                            u"\U00010000-\U0010ffff"
                            u"\u2640-\u2642"
                            u"\u2600-\u2B55"
                            u"\u200d"
                            u"\u23cf"
                            u"\u23e9"
                            u"\u231a"
                            u"\ufe0f"  # dingbats
                            u"\u3030"
                            "]+", flags=re.UNICODE)

    return re.sub(emojis_expression, "", text)

def preprocess(text):
    """
    Clean and tokenize the text

    Argument:
    text -- the text to clean

    Returns:
    text - the list of tokens obtained from the input text.
    """
    stemmer = PorterStemmer()
    stop_words = stopwords.words("english")
    punctuation = r"[!¡?¿.:,;()\[\]{}\-\'\"]"

    text = remove_emojis(text) #Remove emojis
    text = text.strip() #Remove whitespaces at the beginning and at the end
    text = text.lower() ## Transform in lowercase
    text = re.sub(punctuation, "", text) ## Eliminate puntuation marks
    text = text.split() ## Tokenize the text to get a list of terms
    text = [token for token in text if token not in stop_words] ## Eliminate the stopwords
    text = [stemmer.stem(token) for token in text] ## Perform stemming

    return text

# %%
def search(query, index):
    """
    The output is the list of documents that contain any of the query terms.
    So, we will get the list of documents for each query term, and take the union of them.

    Argument:

    query -- name of the query
    index -- created index


    Returns:
    docs - list of tweets IDs and url of the term of the query
    """

    #first we clean and tokenize the query
    query = preprocess(query)
    docs = set()
    #loop trough every word in the query
    for term in query:
        try:
            # store in term_docs the ids of the docs that contain "term"
            term_docs=[posting[0] for posting in index[term]]
            # docs = docs Union term_docs
            docs = docs.union(term_docs)
        except:
            #term is not in index
            pass
    docs = list(docs)
    return docs

# %%
#Search the tweet id of the first query
query1 = "Zelenski"
docs = search(query1, index)
#Get 20 samples of tweets
top = 20
id_to_tweet = {tweet['id']: id for id, tweet in enumerate(tweets)}

print("\n======================\nSample of {} results out of {} for the query {}:\n".format(top, len(docs), query1))
for d_id in docs[:top]:
     print("tweet id = {} - tweet: {}".format(d_id, tweets[d_id-1]["url"]))
# Out:
# ======================
# Sample of 20 results out of 36 for the query Zelenski:
#
# tweet id = 131 - tweet: https://twitter.com/FreeCiviliansUA/status/1575905170952982528
# tweet id = 3210 - tweet: https://twitter.com/FreeCiviliansUA/status/1575272563902746624
# tweet id = 2318 - tweet: https://twitter.com/Militarylandnet/status/1575510001594015744
# tweet id = 783 - tweet: https://twitter.com/Conor_Dempsey/status/1575820638362574848
# tweet id = 3087 - tweet: https://twitter.com/slim_swede/status/1575315693905580032
# tweet id = 1300 - tweet: https://twitter.com/AnnevelinkD/status/1575759357370736640
# tweet id = 150 - tweet: https://twitter.com/Kegan653/status/1575902847216095232
# tweet id = 408 - tweet: https://twitter.com/NEWS_ALL_TIME/status/1575861873060499456
# tweet id = 411 - tweet: https://twitter.com/knittingknots/status/1575861425133981696
# tweet id = 2078 - tweet: https://twitter.com/G700Sway/status/1575573525024251904
# tweet id = 287 - tweet: https://twitter.com/Shadi_Alkasim/status/1575885728701026304
# tweet id = 417 - tweet: https://twitter.com/Chronology22/status/1575860740556460032
# tweet id = 3879 - tweet: https://twitter.com/djjarman/status/1575169420661760000
# tweet id = 1197 - tweet: https://twitter.com/nehakhanna_07/status/1575782059066691584
# tweet id = 430 - tweet: https://twitter.com/knittingknots/status/1575858809842503680
# tweet id = 3506 - tweet: https://twitter.com/Daily_Express/status/1575211259833864192
# tweet id = 183 - tweet: https://twitter.com/NewsZapper/status/1575899185202724864
# tweet id = 442 - tweet: https://twitter.com/Chronology22/status/1575857124877295616
# tweet id = 447 - tweet: https://twitter.com/Magnifyingglas_/status/1575855639011549184
# tweet id = 1218 - tweet: https://twitter.com/PatilSushmit/status/1575776384324374528

# %%
#Second query
query2 = "Crimea"
docs = search(query2, index)
top = 20

print("\n======================\nSample of {} results out of {} for the query {}:\n".format(top, len(docs), query2))
for d_id in docs[:top]:
     print("tweet id = {} - tweet: {}".format(d_id, tweets[d_id-1]["url"]))
# Out:
# ======================
# Sample of 20 results out of 26 for the query Crimea:
#
# tweet id = 3856 - tweet: https://twitter.com/K13News/status/1575173336665300992
# tweet id = 2197 - tweet: https://twitter.com/DarwinBedford/status/1575538366179057664
# tweet id = 2453 - tweet: https://twitter.com/infussambas/status/1575476108077985792
# tweet id = 2336 - tweet: https://twitter.com/knittingknots/status/1575505128337309696
# tweet id = 3361 - tweet: https://twitter.com/Odessa_Journal/status/1575241438937239552
# tweet id = 170 - tweet: https://twitter.com/NBRnews/status/1575900221141241856
# tweet id = 3883 - tweet: https://twitter.com/andreleoso/status/1575168930389569536
# tweet id = 175 - tweet: https://twitter.com/knittingknots/status/1575899953456877568
# tweet id = 3506 - tweet: https://twitter.com/Daily_Express/status/1575211259833864192
# tweet id = 59 - tweet: https://twitter.com/K13News/status/1575910964112740352
# tweet id = 317 - tweet: https://twitter.com/ukrainewar24/status/1575880417286160384
# tweet id = 321 - tweet: https://twitter.com/NEWS_ALL_TIME/status/1575880127262904320
# tweet id = 3649 - tweet: https://twitter.com/knittingknots/status/1575193723364950016
# tweet id = 456 - tweet: https://twitter.com/FreeCiviliansUA/status/1575854630592217088
# tweet id = 462 - tweet: https://twitter.com/UKikaski/status/1575854089707335680
# tweet id = 3281 - tweet: https://twitter.com/NEWS_ALL_TIME/status/1575253795352809472
# tweet id = 210 - tweet: https://twitter.com/zardoz82013/status/1575896342744141824
# tweet id = 2131 - tweet: https://twitter.com/ArtemZhuk2/status/1575553822264819712
# tweet id = 3922 - tweet: https://twitter.com/FCU_Ukraine/status/1575162775915069440
# tweet id = 1109 - tweet: https://twitter.com/KohnNatan/status/1575793173062127616

# %%
#Third query
query3 = "Civilians"
docs = search(query3, index)
top = 20

print("\n======================\nSample of {} results out of {} for the query {}:\n".format(top, len(docs), query3))
for d_id in docs[:top]:
     print("tweet id = {} - tweet: {}".format(d_id, tweets[d_id-1]["url"]))
# Out:
# ======================
# Sample of 20 results out of 88 for the query Civilians:
#
# tweet id = 1025 - tweet: https://twitter.com/MrFukkew/status/1575800190669586432
# tweet id = 1027 - tweet: https://twitter.com/Ventured446/status/1575800139658440704
# tweet id = 3593 - tweet: https://twitter.com/knittingknots/status/1575201082279862272
# tweet id = 1040 - tweet: https://twitter.com/MoRaY1959/status/1575798982735204352
# tweet id = 3134 - tweet: https://twitter.com/knittingknots/status/1575301220390129664
# tweet id = 67 - tweet: https://twitter.com/QUICKMAGAZIN/status/1575909988618231808
# tweet id = 1110 - tweet: https://twitter.com/oimmao/status/1575793139595427840
# tweet id = 1120 - tweet: https://twitter.com/MxmLurie/status/1575791448431030272
# tweet id = 1121 - tweet: https://twitter.com/MrFukkew/status/1575791204855607296
# tweet id = 615 - tweet: https://twitter.com/ActForUA/status/1575830547472912384
# tweet id = 3183 - tweet: https://twitter.com/W7VOA/status/1575283090162860032
# tweet id = 637 - tweet: https://twitter.com/logoh/status/1575828994825461760
# tweet id = 1679 - tweet: https://twitter.com/Suspended_Acct/status/1575648016060805120
# tweet id = 144 - tweet: https://twitter.com/NewsZapper/status/1575903604229443584
# tweet id = 1174 - tweet: https://twitter.com/theSundaily/status/1575786511978885120
# tweet id = 3235 - tweet: https://twitter.com/Breakin93830661/status/1575263511604736000
# tweet id = 1188 - tweet: https://twitter.com/WorldAffairsPro/status/1575784011963990016
# tweet id = 1197 - tweet: https://twitter.com/nehakhanna_07/status/1575782059066691584
# tweet id = 1202 - tweet: https://twitter.com/WeAreProtestors/status/1575781221057310720
# tweet id = 1204 - tweet: https://twitter.com/WeAreProtestors/status/1575781113624088576

# %%
#Fourth query
query4 = "NATO"
docs = search(query4, index)
top = 20

print("\n======================\nSample of {} results out of {} for the query {}:\n".format(top, len(docs), query4))
for d_id in docs[:top]:
     print("tweet id = {} - tweet: {}".format(d_id, tweets[d_id-1]["url"]))
# Out:
# ======================
# Sample of 20 results out of 121 for the query NATO:
#
# tweet id = 6 - tweet: https://twitter.com/NEWS_ALL_TIME/status/1575917759707299840
# tweet id = 7 - tweet: https://twitter.com/A0zeir/status/1575917751360593920
# tweet id = 2569 - tweet: https://twitter.com/CuriosityGuide/status/1575458088760516608
# tweet id = 27 - tweet: https://twitter.com/Amannatt/status/1575914279295156224
# tweet id = 2590 - tweet: https://twitter.com/CuriosityGuide/status/1575457685679513600
# tweet id = 2595 - tweet: https://twitter.com/CuriosityGuide/status/1575457536387563520
# tweet id = 2597 - tweet: https://twitter.com/CuriosityGuide/status/1575457478745153536
# tweet id = 3629 - tweet: https://twitter.com/raffles2004/status/1575196069683597312
# tweet id = 50 - tweet: https://twitter.com/casulers/status/1575911896447913984
# tweet id = 54 - tweet: https://twitter.com/TrimiA98/status/1575911455806742528
# tweet id = 69 - tweet: https://twitter.com/_BrandonSulliva/status/1575909930481205248
# tweet id = 74 - tweet: https://twitter.com/_BrandonSulliva/status/1575909522849550336
# tweet id = 1103 - tweet: https://twitter.com/EUFreeCitizen/status/1575793489228443648
# tweet id = 2129 - tweet: https://twitter.com/nbeast17/status/1575555495624339456
# tweet id = 83 - tweet: https://twitter.com/elevotv/status/1575909051380432896
# tweet id = 94 - tweet: https://twitter.com/OyuluPatrick/status/1575908174343069696
# tweet id = 95 - tweet: https://twitter.com/_BrandonSulliva/status/1575908142948532224
# tweet id = 97 - tweet: https://twitter.com/Suspended_Acct/status/1575908120294891520
# tweet id = 99 - tweet: https://twitter.com/knittingknots/status/1575908078352039936
# tweet id = 100 - tweet: https://twitter.com/elevotv/status/1575908043891437568

# %%
#Fifth query
query5 = "Negotiations"
docs = search(query5, index)
top = 20

print("\n======================\nSample of {} results out of {} for the query {}:\n".format(top, len(docs), query5))
for d_id in docs[:top]:
     print("tweet id = {} - tweet: {}".format(d_id, tweets[d_id-1]["url"]))
# Out:
# ======================
# Sample of 20 results out of 37 for the query Negotiations:
#
# tweet id = 515 - tweet: https://twitter.com/u_me_reality/status/1575845160134451200
# tweet id = 643 - tweet: https://twitter.com/firamnews/status/1575828204702806016
# tweet id = 1799 - tweet: https://twitter.com/The_Old_Hippie/status/1575633805288779776
# tweet id = 659 - tweet: https://twitter.com/_Nex3_/status/1575827009048956928
# tweet id = 3991 - tweet: https://twitter.com/FPVDroneNerd/status/1575155283613155328
# tweet id = 24 - tweet: https://twitter.com/Shadi_Alkasim/status/1575914711388139520
# tweet id = 415 - tweet: https://twitter.com/Chronology22/status/1575861001769013248
# tweet id = 3872 - tweet: https://twitter.com/1002spvr/status/1575170727904309248
# tweet id = 417 - tweet: https://twitter.com/Chronology22/status/1575860740556460032
# tweet id = 2214 - tweet: https://twitter.com/potuspl/status/1575534709144227840
# tweet id = 3878 - tweet: https://twitter.com/TimeToWakeUp247/status/1575169694822445056
# tweet id = 41 - tweet: https://twitter.com/OneVenusThrow/status/1575912858004561920
# tweet id = 1579 - tweet: https://twitter.com/ifomohard/status/1575674005297561600
# tweet id = 687 - tweet: https://twitter.com/NEWS_ALL_TIME/status/1575825370061844480
# tweet id = 3123 - tweet: https://twitter.com/GranataLLC/status/1575304304004562944
# tweet id = 3764 - tweet: https://twitter.com/BlogUkraine/status/1575182093973233664
# tweet id = 55 - tweet: https://twitter.com/arq_trejo/status/1575911381534388224
# tweet id = 3642 - tweet: https://twitter.com/The_Old_Hippie/status/1575194189498703872
# tweet id = 699 - tweet: https://twitter.com/Amannatt/status/1575825005291524096
# tweet id = 189 - tweet: https://twitter.com/UkraineWarPic/status/1575898746868695040

# %% [markdown]
# ### Ranking

# %%
def create_index_tfidf(tweets, num_documents):
    """
    Implement the inverted index and compute tf, df and idf

    Argument:
    tweets -- collection of tweeets
    num_documents -- total number of documents

    Returns:
    index - the inverted index (implemented through a Python dictionary) containing terms as keys and the corresponding
    list of document these keys appears in (and the positions) as values.
    tf - normalized term frequency for each term in each document
    df - number of documents each term appear in
    idf - inverse document frequency of each term
    """

    index = defaultdict(list)
    tf = defaultdict(list)  # term frequencies of terms in documents (documents in the same order as in the main index)
    df = defaultdict(int)  # document frequencies of terms in the corpus
    title_index = defaultdict(str)
    idf = defaultdict(float)

    for idx, tweet in enumerate(tweets):  #Iterate through the tweets
        tweet_id = idx+1 #calculate tweet_id
        terms = tweet["full_text_tokenized"] #get full tokenized text of the tweet

        current_page_index = {}

        for position, term in enumerate(terms):
            try:
                # if the term is already in the dict append the position to the corresponding list
                current_page_index[term][1].append(position)
            except:
                # Add the new term as dict key and initialize the array of positions and add the position
                current_page_index[term]=[tweet_id, array('I',[position])] #'I' indicates unsigned int (int in Python)

        #normalize term frequencies
        # Compute the denominator to normalize term frequencies
        # norm is the same for all terms of a document.
        norm = 0
        for term, posting in current_page_index.items():
            # posting will contain the list of positions for current term in current document.
            norm += len(posting[1]) ** 2
        norm = math.sqrt(norm)

        # calculate the tf and df weights
        for term, posting in current_page_index.items():
            # append the tf for current term (tf = term frequency in current doc/norm)
            tf[term].append(np.round(len(posting[1])/norm,4))
            #increment the document frequency of current term (number of documents containing the current term)
            df[term] = df[term] + 1 # increment DF for current term

        #merge the current page index with the main index
        for term_page, posting_page in current_page_index.items():
            index[term_page].append(posting_page)

        # Compute IDF
        for term in df:
            idf[term] = np.round(np.log(float(num_documents/df[term])), 4)

    return index, tf, df, idf

# %%
index
# Out:
# defaultdict(list,
#             {'@melsimmonsfcdo': [[1, array('I', [0])]],
#              'wrong': [[1, array('I', [1])],
#               [25, array('I', [10])],
#               [256, array('I', [1, 3])],
#               [327, array('I', [6])],
#               [445, array('I', [4])],
#               [1322, array('I', [4])],
#               [1498, array('I', [6])],
#               [1512, array('I', [0])],
#               [1596, array('I', [6])],
#               [2093, array('I', [8])],
#               [2157, array('I', [1])],
#               [2207, array('I', [8])],
#               [2236, array('I', [6])],
#               [2237, array('I', [6])],
#               [3714, array('I', [4])],
#               [3844, array('I', [5])],
#               [3900, array('I', [6])],
#               [3947, array('I', [8])],
#               [3994, array('I', [3])]],
#              'dictat': [[1, array('I', [2])],
#               [199, array('I', [2])],
#               [225, array('I', [1])],
#               [240, array('I', [6])],
#               [666, array('I', [9])],
#               [1495, array('I', [5])],
#               [1862, array('I', [1])],
#               [2674, array('I', [16])],
#               [2963, array('I', [21])],
#               [3115, array('I', [2])]],
#              'putin': [[1, array('I', [3])],
#               [9, array('I', [4])],
#               [16, array('I', [4, 12])],
#               [22, array('I', [2])],
#               [23, array('I', [1])],
#               [47, array('I', [9])],
#               [50, array('I', [11])],
#               [52, array('I', [4])],
#               [53, array('I', [0])],
#               [56, array('I', [1])],
#               [62, array('I', [5])],
#               [64, array('I', [0, 9])],
#               [73, array('I', [0])],
#               [94, array('I', [7])],
#               [97, array('I', [7])],
#               [99, array('I', [3])],
#               [108, array('I', [0])],
#               [112, array('I', [5])],
#               [118, array('I', [2])],
#               [119, array('I', [15])],
#               [131, array('I', [1])],
#               [133, array('I', [0])],
#               [136, array('I', [1])],
#               [146, array('I', [3])],
#               [152, array('I', [1])],
#               [154, array('I', [4])],
#               [160, array('I', [5, 16])],
#               [163, array('I', [11])],
#               [177, array('I', [3, 16])],
#               [179, array('I', [3, 16])],
#               [183, array('I', [5])],
#               [189, array('I', [7])],
#               [191, array('I', [3])],
#               [194, array('I', [2])],
#               [200, array('I', [21])],
#               [210, array('I', [16])],
#               [224, array('I', [5])],
#               [228, array('I', [3])],
#               [232, array('I', [0])],
#               [240, array('I', [7])],
#               [245, array('I', [5])],
#               [246, array('I', [0])],
#               [247, array('I', [4])],
#               [258, array('I', [1])],
#               [272, array('I', [1])],
#               [281, array('I', [4])],
#               [284, array('I', [4])],
#               [289, array('I', [2])],
#               [295, array('I', [8])],
#               [298, array('I', [1])],
#               [305, array('I', [0])],
#               [307, array('I', [1])],
#               [312, array('I', [0])],
#               [318, array('I', [4])],
#               [333, array('I', [17])],
#               [349, array('I', [7])],
#               [353, array('I', [0])],
#               [358, array('I', [4])],
#               [364, array('I', [7])],
#               [372, array('I', [1])],
#               [380, array('I', [4])],
#               [382, array('I', [9])],
#               [384, array('I', [4])],
#               [386, array('I', [0])],
#               [387, array('I', [1])],
#               [389, array('I', [2])],
#               [400, array('I', [7])],
#               [402, array('I', [2])],
#               [415, array('I', [3])],
#               [417, array('I', [4])],
#               [421, array('I', [3])],
#               [423, array('I', [0])],
#               [450, array('I', [4])],
#               [454, array('I', [0])],
#               [465, array('I', [8])],
#               [485, array('I', [0])],
#               [497, array('I', [4])],
#               [498, array('I', [1])],
#               [501, array('I', [4])],
#               [507, array('I', [3])],
#               [513, array('I', [2])],
#               [516, array('I', [3])],
#               [517, array('I', [0])],
#               [524, array('I', [0])],
#               [525, array('I', [0])],
#               [529, array('I', [12])],
#               [531, array('I', [13])],
#               [537, array('I', [5])],
#               [541, array('I', [0])],
#               [556, array('I', [0])],
#               [568, array('I', [5])],
#               [570, array('I', [0])],
#               [577, array('I', [3])],
#               [580, array('I', [2])],
#               [585, array('I', [3])],
#               [591, array('I', [3])],
#               [593, array('I', [1])],
#               [600, array('I', [4])],
#               [602, array('I', [13])],
#               [604, array('I', [0])],
#               [605, array('I', [3])],
#               [610, array('I', [4])],
#               [613, array('I', [0])],
#               [616, array('I', [0])],
#               [618, array('I', [5])],
#               [621, array('I', [2])],
#               [623, array('I', [0])],
#               [624, array('I', [0])],
#               [626, array('I', [5])],
#               [627, array('I', [10])],
#               [628, array('I', [0])],
#               [630, array('I', [9])],
#               [632, array('I', [5])],
#               [633, array('I', [0])],
#               [636, array('I', [0])],
#               [641, array('I', [0])],
#               [642, array('I', [7])],
#               [643, array('I', [1])],
#               [644, array('I', [2])],
#               [645, array('I', [10])],
#               [647, array('I', [0, 9])],
#               [648, array('I', [4])],
#               [650, array('I', [1])],
#               [653, array('I', [4])],
#               [654, array('I', [2])],
#               [655, array('I', [3])],
#               [656, array('I', [5])],
#               [657, array('I', [2])],
#               [658, array('I', [7])],
#               [659, array('I', [3])],
#               [668, array('I', [0])],
#               [670, array('I', [0])],
#               [672, array('I', [0])],
#               [673, array('I', [0])],
#               [677, array('I', [7])],
#               [684, array('I', [0])],
#               [687, array('I', [0])],
#               [692, array('I', [0])],
#               [699, array('I', [0])],
#               [703, array('I', [1])],
#               [704, array('I', [5])],
#               [705, array('I', [0])],
#               [708, array('I', [14])],
#               [711, array('I', [11])],
#               [712, array('I', [1])],
#               [716, array('I', [0])],
#               [720, array('I', [0])],
#               [722, array('I', [2])],
#               [724, array('I', [0])],
#               [725, array('I', [8])],
#               [728, array('I', [0])],
#               [730, array('I', [0])],
#               [735, array('I', [16])],
#               [737, array('I', [0])],
#               [742, array('I', [0])],
#               [759, array('I', [4])],
#               [766, array('I', [3, 11, 15])],
#               [767, array('I', [3])],
#               [810, array('I', [11])],
#               [819, array('I', [3])],
#               [821, array('I', [0])],
#               [903, array('I', [7])],
#               [926, array('I', [5])],
#               [928, array('I', [4])],
#               [944, array('I', [4])],
#               [945, array('I', [0])],
#               [964, array('I', [1])],
#               [966, array('I', [5])],
#               [1005, array('I', [6])],
#               [1008, array('I', [0])],
#               [1036, array('I', [4])],
#               [1040, array('I', [8])],
#               [1049, array('I', [2])],
#               [1053, array('I', [4])],
#               [1064, array('I', [4])],
#               [1071, array('I', [4, 7, 10])],
#               [1100, array('I', [9])],
#               [1129, array('I', [1])],
#               [1138, array('I', [0])],
#               [1184, array('I', [3])],
#               [1186, array('I', [18])],
#               [1211, array('I', [4])],
#               [1213, array('I', [11])],
#               [1226, array('I', [4])],
#               [1274, array('I', [2])],
#               [1282, array('I', [0])],
#               [1313, array('I', [2])],
#               [1317, array('I', [4])],
#               [1326, array('I', [4])],
#               [1341, array('I', [4])],
#               [1345, array('I', [4])],
#               [1348, array('I', [12])],
#               [1354, array('I', [11])],
#               [1355, array('I', [4])],
#               [1373, array('I', [5])],
#               [1377, array('I', [4])],
#               [1387, array('I', [2])],
#               [1389, array('I', [5])],
#               [1401, array('I', [2])],
#               [1444, array('I', [4])],
#               [1455, array('I', [2])],
#               [1460, array('I', [4])],
#               [1464, array('I', [2])],
#               [1474, array('I', [5])],
#               [1478, array('I', [8])],
#               [1489, array('I', [2])],
#               [1502, array('I', [0])],
#               [1527, array('I', [23])],
#               [1530, array('I', [5])],
#               [1538, array('I', [4])],
#               [1542, array('I', [2])],
#               [1556, array('I', [9])],
#               [1572, array('I', [3])],
#               [1581, array('I', [0])],
#               [1587, array('I', [8])],
#               [1588, array('I', [14])],
#               [1589, array('I', [2])],
#               [1593, array('I', [1])],
#               [1615, array('I', [1])],
#               [1616, array('I', [11])],
#               [1620, array('I', [0, 12])],
#               [1627, array('I', [22])],
#               [1630, array('I', [6])],
#               [1634, array('I', [1])],
#               [1648, array('I', [4])],
#               [1654, array('I', [4])],
#               [1663, array('I', [0])],
#               [1669, array('I', [1])],
#               [1686, array('I', [0])],
#               [1687, array('I', [4])],
#               [1694, array('I', [3])],
#               [1697, array('I', [10])],
#               [1703, array('I', [0])],
#               [1711, array('I', [6])],
#               [1713, array('I', [3])],
#               [1727, array('I', [4])],
#               [1736, array('I', [3, 11, 15])],
#               [1737, array('I', [3])],
#               [1739, array('I', [2])],
#               [1754, array('I', [4])],
#               [1763, array('I', [4])],
#               [1781, array('I', [2])],
#               [1790, array('I', [2])],
#               [1802, array('I', [0])],
#               [1819, array('I', [0])],
#               [1821, array('I', [6])],
#               [1825, array('I', [1])],
#               [1828, array('I', [2])],
#               [1849, array('I', [10])],
#               [1856, array('I', [0])],
#               [1862, array('I', [9])],
#               [1865, array('I', [3])],
#               [1866, array('I', [2])],
#               [1868, array('I', [5])],
#               [1885, array('I', [5])],
#               [1886, array('I', [5])],
#               [1887, array('I', [5])],
#               [1890, array('I', [2])],
#               [1900, array('I', [3])],
#               [1910, array('I', [4])],
#               [1914, array('I', [1])],
#               [1937, array('I', [4])],
#               [1941, array('I', [10])],
#               [1949, array('I', [8])],
#               [1950, array('I', [0])],
#               [1952, array('I', [0])],
#               [1959, array('I', [3])],
#               [1961, array('I', [2])],
#               [1967, array('I', [1])],
#               [1972, array('I', [1])],
#               [1984, array('I', [11])],
#               [1995, array('I', [3])],
#               [2008, array('I', [1])],
#               [2029, array('I', [4])],
#               [2034, array('I', [2])],
#               [2044, array('I', [0])],
#               [2072, array('I', [15])],
#               [2078, array('I', [16])],
#               [2083, array('I', [1])],
#               [2099, array('I', [9])],
#               [2100, array('I', [2])],
#               [2109, array('I', [7])],
#               [2111, array('I', [7, 12])],
#               [2126, array('I', [4])],
#               [2128, array('I', [4])],
#               [2145, array('I', [5])],
#               [2149, array('I', [0])],
#               [2151, array('I', [2])],
#               [2177, array('I', [7])],
#               [2179, array('I', [8])],
#               [2186, array('I', [2])],
#               [2197, array('I', [1])],
#               [2200, array('I', [4])],
#               [2250, array('I', [5])],
#               [2287, array('I', [3])],
#               [2299, array('I', [0])],
#               [2333, array('I', [0])],
#               [2355, array('I', [2])],
#               [2362, array('I', [2])],
#               [2371, array('I', [8])],
#               [2383, array('I', [13])],
#               [2412, array('I', [4])],
#               [2421, array('I', [3])],
#               [2423, array('I', [6])],
#               [2465, array('I', [0])],
#               [2470, array('I', [9])],
#               [2530, array('I', [8])],
#               [2553, array('I', [2])],
#               [2560, array('I', [4])],
#               [2569, array('I', [6])],
#               [2571, array('I', [3])],
#               [2584, array('I', [4])],
#               [2594, array('I', [3, 11, 15])],
#               [2595, array('I', [3])],
#               [2597, array('I', [2])],
#               [2616, array('I', [5])],
#               [2621, array('I', [10])],
#               [2630, array('I', [2])],
#               [2637, array('I', [2])],
#               [2640, array('I', [0])],
#               [2673, array('I', [0])],
#               [2683, array('I', [1])],
#               [2693, array('I', [20])],
#               [2696, array('I', [15])],
#               [2720, array('I', [0, 13])],
#               [2724, array('I', [3])],
#               [2756, array('I', [19])],
#               [2757, array('I', [3])],
#               [2769, array('I', [4])],
#               [2787, array('I', [4])],
#               [2804, array('I', [9])],
#               [2818, array('I', [0])],
#               [2843, array('I', [4])],
#               [2899, array('I', [4])],
#               [2913, array('I', [2])],
#               [2924, array('I', [2])],
#               [2938, array('I', [14])],
#               [2946, array('I', [19])],
#               [2950, array('I', [2])],
#               [2958, array('I', [4])],
#               [2963, array('I', [2])],
#               [2970, array('I', [2])],
#               [2988, array('I', [11])],
#               [2989, array('I', [4])],
#               [2990, array('I', [2])],
#               [2993, array('I', [4])],
#               [3001, array('I', [5])],
#               [3018, array('I', [1])],
#               [3022, array('I', [2])],
#               [3026, array('I', [4])],
#               [3032, array('I', [0, 9])],
#               [3047, array('I', [11])],
#               [3052, array('I', [4])],
#               [3075, array('I', [2])],
#               [3080, array('I', [2])],
#               [3082, array('I', [0, 12])],
#               [3085, array('I', [4])],
#               [3086, array('I', [4])],
#               [3089, array('I', [9])],
#               [3112, array('I', [6])],
#               [3114, array('I', [4])],
#               [3139, array('I', [6])],
#               [3151, array('I', [9])],
#               [3186, array('I', [8])],
#               [3204, array('I', [3])],
#               [3216, array('I', [13])],
#               [3228, array('I', [0])],
#               [3240, array('I', [0])],
#               [3250, array('I', [5])],
#               [3265, array('I', [4])],
#               [3276, array('I', [4])],
#               [3287, array('I', [0, 8])],
#               [3303, array('I', [3])],
#               [3310, array('I', [4])],
#               [3331, array('I', [15])],
#               [3392, array('I', [4])],
#               [3405, array('I', [14])],
#               [3417, array('I', [0])],
#               [3422, array('I', [8])],
#               [3431, array('I', [11])],
#               [3432, array('I', [2])],
#               [3436, array('I', [11])],
#               [3444, array('I', [4])],
#               [3449, array('I', [2])],
#               [3450, array('I', [4])],
#               [3460, array('I', [1, 18])],
#               [3510, array('I', [7])],
#               [3538, array('I', [0])],
#               [3539, array('I', [0])],
#               [3540, array('I', [3])],
#               [3544, array('I', [6])],
#               [3548, array('I', [6])],
#               [3554, array('I', [1])],
#               [3564, array('I', [0, 12])],
#               [3565, array('I', [0])],
#               [3567, array('I', [0])],
#               [3593, array('I', [0])],
#               [3598, array('I', [4])],
#               [3603, array('I', [3])],
#               [3608, array('I', [5])],
#               [3629, array('I', [8])],
#               [3662, array('I', [2])],
#               [3693, array('I', [21])],
#               [3695, array('I', [4])],
#               [3714, array('I', [13, 19])],
#               [3735, array('I', [7])],
#               [3741, array('I', [13])],
#               [3759, array('I', [5])],
#               [3765, array('I', [5])],
#               [3776, array('I', [2])],
#               [3778, array('I', [13])],
#               [3792, array('I', [0])],
#               [3794, array('I', [1])],
#               [3800, array('I', [3])],
#               [3812, array('I', [0])],
#               [3818, array('I', [0])],
#               [3821, array('I', [0])],
#               [3851, array('I', [3])],
#               [3879, array('I', [9])],
#               [3884, array('I', [2])],
#               [3888, array('I', [8, 13])],
#               [3897, array('I', [8])],
#               [3901, array('I', [2])],
#               [3915, array('I', [13])],
#               [3934, array('I', [4])],
#               [3937, array('I', [1])],
#               [3941, array('I', [2])],
#               [3958, array('I', [3])],
#               [3972, array('I', [0])],
#               [3982, array('I', [2])],
#               [3983, array('I', [13])],
#               [3990, array('I', [16])],
#               [3996, array('I', [15])],
#               [3999, array('I', [18])]],
#              'fascist': [[1, array('I', [4])],
#               [136, array('I', [7])],
#               [230, array('I', [3])],
#               [240, array('I', [11])],
#               [413, array('I', [1])],
#               [437, array('I', [7])],
#               [2403, array('I', [4])],
#               [2954, array('I', [1])],
#               [3853, array('I', [4])]],
#              'russia': [[1, array('I', [5])],
#               [4, array('I', [6])],
#               [7, array('I', [4, 8])],
#               [8, array('I', [5])],
#               [9, array('I', [0, 7, 8, 9])],
#               [11, array('I', [6])],
#               [20, array('I', [8])],
#               [28, array('I', [6])],
#               [31, array('I', [21])],
#               [47, array('I', [15])],
#               [48, array('I', [0])],
#               [63, array('I', [3])],
#               [64, array('I', [4])],
#               [81, array('I', [3])],
#               [87, array('I', [3])],
#               [88, array('I', [7])],
#               [97, array('I', [5])],
#               [111, array('I', [7, 17])],
#               [130, array('I', [11])],
#               [136, array('I', [3])],
#               [141, array('I', [1])],
#               [148, array('I', [0])],
#               [153, array('I', [10, 20])],
#               [156, array('I', [7])],
#               [186, array('I', [0])],
#               [195, array('I', [7])],
#               [198, array('I', [0, 8])],
#               [200, array('I', [14])],
#               [204, array('I', [5])],
#               [210, array('I', [6, 11, 22])],
#               [212, array('I', [10])],
#               [221, array('I', [7])],
#               [233, array('I', [8])],
#               [239, array('I', [0])],
#               [248, array('I', [2])],
#               [260, array('I', [5])],
#               [273, array('I', [4])],
#               [291, array('I', [8])],
#               [295, array('I', [2, 3, 4])],
#               [296, array('I', [5])],
#               [307, array('I', [0])],
#               [309, array('I', [3])],
#               [315, array('I', [7])],
#               [322, array('I', [5])],
#               [340, array('I', [2])],
#               [341, array('I', [6])],
#               [343, array('I', [0])],
#               [353, array('I', [7])],
#               [373, array('I', [5])],
#               [375, array('I', [19])],
#               [380, array('I', [3])],
#               [382, array('I', [2])],
#               [385, array('I', [10])],
#               [386, array('I', [9])],
#               [392, array('I', [5])],
#               [393, array('I', [13])],
#               [395, array('I', [12])],
#               [403, array('I', [6])],
#               [407, array('I', [2])],
#               [411, array('I', [2])],
#               [414, array('I', [5])],
#               [416, array('I', [9])],
#               [417, array('I', [3])],
#               [418, array('I', [7])],
#               [470, array('I', [2])],
#               [473, array('I', [18])],
#               [482, array('I', [0])],
#               [485, array('I', [9])],
#               [488, array('I', [3])],
#               [490, array('I', [6])],
#               [491, array('I', [17])],
#               [499, array('I', [9])],
#               [505, array('I', [7, 12])],
#               [507, array('I', [1])],
#               [520, array('I', [1])],
#               [521, array('I', [4])],
#               [524, array('I', [8])],
#               [531, array('I', [10])],
#               [534, array('I', [12])],
#               [543, array('I', [18])],
#               [554, array('I', [9])],
#               [555, array('I', [5])],
#               [558, array('I', [0])],
#               [560, array('I', [8])],
#               [561, array('I', [7])],
#               [567, array('I', [0])],
#               [568, array('I', [2, 3, 4])],
#               [575, array('I', [14])],
#               [576, array('I', [4])],
#               [587, array('I', [1, 5, 10])],
#               [601, array('I', [1, 5, 10])],
#               [612, array('I', [2])],
#               [615, array('I', [11])],
#               [619, array('I', [9])],
#               [624, array('I', [4])],
#               [632, array('I', [10])],
#               [633, array('I', [11])],
#               [641, array('I', [4])],
#               [643, array('I', [12])],
#               [650, array('I', [6])],
#               [661, array('I', [0, 4, 9])],
#               [668, array('I', [2])],
#               [671, array('I', [2])],
#               [682, array('I', [0])],
#               [708, array('I', [7])],
#               [711, array('I', [10])],
#               [713, array('I', [1])],
#               [720, array('I', [4])],
#               [728, array('I', [4])],
#               [752, array('I', [5])],
#               [760, array('I', [8])],
#               [762, array('I', [6])],
#               [763, array('I', [2])],
#               [777, array('I', [1])],
#               [784, array('I', [6])],
#               [802, array('I', [6])],
#               [807, array('I', [5])],
#               [809, array('I', [2])],
#               [810, array('I', [10])],
#               [813, array('I', [4, 12])],
#               [823, array('I', [0])],
#               [834, array('I', [4])],
#               [845, array('I', [1])],
#               [868, array('I', [23])],
#               [869, array('I', [15])],
#               [883, array('I', [2])],
#               [904, array('I', [2])],
#               [911, array('I', [3])],
#               [938, array('I', [8, 9])],
#               [948, array('I', [3])],
#               [956, array('I', [2])],
#               [960, array('I', [6])],
#               [962, array('I', [11])],
#               [985, array('I', [2])],
#               [987, array('I', [0])],
#               [1007, array('I', [1])],
#               [1009, array('I', [5])],
#               [1016, array('I', [7])],
#               [1028, array('I', [18])],
#               [1041, array('I', [4])],
#               [1042, array('I', [4])],
#               [1049, array('I', [12])],
#               [1050, array('I', [1])],
#               [1058, array('I', [0])],
#               [1061, array('I', [3])],
#               [1065, array('I', [1])],
#               [1071, array('I', [6])],
#               [1092, array('I', [3])],
#               [1099, array('I', [1])],
#               [1100, array('I', [6, 20, 23])],
#               [1127, array('I', [7])],
#               [1140, array('I', [17])],
#               [1180, array('I', [4, 11])],
#               [1197, array('I', [5])],
#               [1203, array('I', [8])],
#               [1205, array('I', [10])],
#               [1213, array('I', [10])],
#               [1214, array('I', [1])],
#               [1222, array('I', [0])],
#               [1223, array('I', [5])],
#               [1241, array('I', [5])],
#               [1252, array('I', [17])],
#               [1262, array('I', [6])],
#               [1276, array('I', [0, 17])],
#               [1288, array('I', [3])],
#               [1295, array('I', [10])],
#               [1300, array('I', [2, 13])],
#               [1311, array('I', [13])],
#               [1319, array('I', [5])],
#               [1322, array('I', [8])],
#               [1337, array('I', [19])],
#               [1343, array('I', [6, 12])],
#               [1348, array('I', [8])],
#               [1350, array('I', [8])],
#               [1358, array('I', [8])],
#               [1375, array('I', [19])],
#               [1397, array('I', [11])],
#               [1414, array('I', [0])],
#               [1417, array('I', [0])],
#               [1419, array('I', [15])],
#               [1462, array('I', [5])],
#               [1464, array('I', [15])],
#               [1477, array('I', [0, 14])],
#               [1478, array('I', [5])],
#               [1488, array('I', [2])],
#               [1494, array('I', [0])],
#               [1528, array('I', [0])],
#               [1529, array('I', [10, 20])],
#               [1533, array('I', [0, 14])],
#               [1535, array('I', [2])],
#               [1537, array('I', [9])],
#               [1539, array('I', [8])],
#               [1546, array('I', [0])],
#               [1547, array('I', [12])],
#               [1570, array('I', [1])],
#               [1574, array('I', [6])],
#               [1577, array('I', [7])],
#               [1588, array('I', [1])],
#               [1594, array('I', [14])],
#               [1599, array('I', [7])],
#               [1601, array('I', [0])],
#               [1604, array('I', [0])],
#               [1606, array('I', [19])],
#               [1607, array('I', [5])],
#               [1617, array('I', [12])],
#               [1627, array('I', [19])],
#               [1629, array('I', [0])],
#               [1634, array('I', [9])],
#               [1643, array('I', [7])],
#               [1644, array('I', [0])],
#               [1646, array('I', [9])],
#               [1649, array('I', [4])],
#               [1661, array('I', [5])],
#               [1666, array('I', [6])],
#               [1667, array('I', [18])],
#               [1670, array('I', [9])],
#               [1675, array('I', [9])],
#               [1679, array('I', [5])],
#               [1680, array('I', [4])],
#               [1685, array('I', [9])],
#               [1689, array('I', [4])],
#               [1692, array('I', [17])],
#               [1707, array('I', [16])],
#               [1709, array('I', [8])],
#               [1710, array('I', [7])],
#               [1720, array('I', [5])],
#               [1721, array('I', [5])],
#               [1729, array('I', [8])],
#               [1733, array('I', [6])],
#               [1734, array('I', [2])],
#               [1741, array('I', [3, 16])],
#               [1748, array('I', [4])],
#               [1752, array('I', [5])],
#               [1761, array('I', [2])],
#               [1771, array('I', [11])],
#               [1783, array('I', [0])],
#               [1800, array('I', [11])],
#               [1813, array('I', [0])],
#               [1832, array('I', [11])],
#               [1839, array('I', [2])],
#               [1840, array('I', [0])],
#               [1848, array('I', [11])],
#               [1852, array('I', [1])],
#               [1865, array('I', [11])],
#               [1867, array('I', [0])],
#               [1876, array('I', [7])],
#               [1880, array('I', [13, 21])],
#               [1884, array('I', [8])],
#               [1890, array('I', [11])],
#               [1897, array('I', [0])],
#               [1903, array('I', [10])],
#               [1904, array('I', [9])],
#               [1908, array('I', [0])],
#               [1920, array('I', [2])],
#               [1927, array('I', [7])],
#               [1930, array('I', [16])],
#               [1938, array('I', [2])],
#               [1953, array('I', [3, 8])],
#               [2048, array('I', [20])],
#               [2050, array('I', [0])],
#               [2052, array('I', [0])],
#               [2063, array('I', [13])],
#               [2080, array('I', [4])],
#               [2083, array('I', [14])],
#               [2086, array('I', [2, 23])],
#               [2094, array('I', [9])],
#               [2101, array('I', [0])],
#               [2103, array('I', [0])],
#               [2104, array('I', [6])],
#               [2108, array('I', [9])],
#               [2111, array('I', [4])],
#               [2113, array('I', [0])],
#               [2115, array('I', [10])],
#               [2126, array('I', [6])],
#               [2131, array('I', [10])],
#               [2141, array('I', [6, 10])],
#               [2154, array('I', [5])],
#               [2190, array('I', [0])],
#               [2205, array('I', [3])],
#               [2213, array('I', [9])],
#               [2238, array('I', [0])],
#               [2252, array('I', [4])],
#               [2259, array('I', [17])],
#               [2260, array('I', [4])],
#               [2263, array('I', [5])],
#               [2265, array('I', [4])],
#               [2266, array('I', [4])],
#               [2274, array('I', [10])],
#               [2281, array('I', [18])],
#               [2284, array('I', [8])],
#               [2292, array('I', [8])],
#               [2311, array('I', [3])],
#               [2318, array('I', [18])],
#               [2334, array('I', [7])],
#               [2339, array('I', [2])],
#               [2342, array('I', [0])],
#               [2358, array('I', [5])],
#               [2369, array('I', [6])],
#               [2370, array('I', [4])],
#               [2373, array('I', [0])],
#               [2377, array('I', [7])],
#               [2384, array('I', [8])],
#               [2404, array('I', [10])],
#               [2409, array('I', [4])],
#               [2411, array('I', [8])],
#               [2416, array('I', [5])],
#               [2417, array('I', [5])],
#               [2432, array('I', [4])],
#               [2448, array('I', [0])],
#               [2451, array('I', [2])],
#               [2463, array('I', [5])],
#               [2467, array('I', [5])],
#               [2495, array('I', [1])],
#               [2496, array('I', [9])],
#               [2500, array('I', [13])],
#               [2501, array('I', [13])],
#               [2502, array('I', [13])],
#               [2503, array('I', [13])],
#               [2504, array('I', [3])],
#               [2506, array('I', [13])],
#               [2507, array('I', [13])],
#               [2509, array('I', [13])],
#               [2511, array('I', [13])],
#               [2512, array('I', [13])],
#               [2513, array('I', [13])],
#               [2514, array('I', [13])],
#               [2515, array('I', [13])],
#               [2516, array('I', [13])],
#               [2517, array('I', [13])],
#               [2519, array('I', [13])],
#               [2520, array('I', [13])],
#               [2521, array('I', [13])],
#               [2522, array('I', [13])],
#               [2523, array('I', [13])],
#               [2524, array('I', [13])],
#               [2525, array('I', [13])],
#               [2528, array('I', [4])],
#               [2530, array('I', [0])],
#               [2533, array('I', [1, 9])],
#               [2538, array('I', [3])],
#               [2539, array('I', [0])],
#               [2540, array('I', [7, 13])],
#               [2545, array('I', [7, 13])],
#               [2563, array('I', [4])],
#               [2575, array('I', [5])],
#               [2576, array('I', [5])],
#               [2585, array('I', [8])],
#               [2588, array('I', [7])],
#               [2590, array('I', [6])],
#               [2591, array('I', [4])],
#               [2601, array('I', [19])],
#               [2608, array('I', [5])],
#               [2621, array('I', [7, 16])],
#               [2634, array('I', [0])],
#               [2654, array('I', [0])],
#               [2661, array('I', [2])],
#               [2662, array('I', [9])],
#               [2677, array('I', [2])],
#               [2705, array('I', [0])],
#               [2706, array('I', [6])],
#               [2713, array('I', [0])],
#               [2715, array('I', [23])],
#               [2721, array('I', [2])],
#               [2722, array('I', [7])],
#               [2740, array('I', [6])],
#               [2741, array('I', [8])],
#               [2767, array('I', [10])],
#               [2771, array('I', [3])],
#               [2788, array('I', [4])],
#               [2789, array('I', [2])],
#               [2790, array('I', [4])],
#               [2793, array('I', [4])],
#               [2803, array('I', [10])],
#               [2806, array('I', [6])],
#               [2807, array('I', [4])],
#               [2811, array('I', [12, 21])],
#               [2828, array('I', [0])],
#               [2850, array('I', [7])],
#               [2892, array('I', [10])],
#               [2909, array('I', [6, 11])],
#               [2914, array('I', [11])],
#               [2926, array('I', [5])],
#               [2937, array('I', [3])],
#               [2938, array('I', [25])],
#               [2947, array('I', [5])],
#               [2951, array('I', [14])],
#               [2960, array('I', [5])],
#               [2964, array('I', [0])],
#               [2972, array('I', [3])],
#               [2983, array('I', [8])],
#               [2984, array('I', [9])],
#               [2996, array('I', [1])],
#               [2999, array('I', [5])],
#               [3012, array('I', [3])],
#               [3013, array('I', [0])],
#               [3015, array('I', [13])],
#               [3021, array('I', [9])],
#               [3039, array('I', [7])],
#               [3062, array('I', [7])],
#               [3063, array('I', [0])],
#               [3072, array('I', [9])],
#               [3082, array('I', [13])],
#               [3089, array('I', [15])],
#               [3090, array('I', [0])],
#               [3097, array('I', [5])],
#               [3112, array('I', [0])],
#               [3122, array('I', [5])],
#               [3130, array('I', [6, 17])],
#               [3132, array('I', [11])],
#               [3135, array('I', [2])],
#               [3177, array('I', [5])],
#               [3189, array('I', [5])],
#               [3190, array('I', [0])],
#               [3191, array('I', [0])],
#               [3210, array('I', [9])],
#               [3213, array('I', [21])],
#               [3217, array('I', [1, 7])],
#               [3228, array('I', [15])],
#               [3240, array('I', [3])],
#               [3243, array('I', [10])],
#               [3250, array('I', [4])],
#               [3251, array('I', [4, 16])],
#               [3258, array('I', [6])],
#               [3266, array('I', [6])],
#               [3270, array('I', [6])],
#               [3271, array('I', [3])],
#               [3297, array('I', [4])],
#               [3323, array('I', [0])],
#               [3331, array('I', [17])],
#               [3355, array('I', [10])],
#               [3360, array('I', [4])],
#               [3361, array('I', [19])],
#               [3369, array('I', [0])],
#               [3373, array('I', [4])],
#               [3378, array('I', [20])],
#               [3379, array('I', [6])],
#               [3403, array('I', [9])],
#               [3407, array('I', [3])],
#               [3417, array('I', [3])],
#               [3422, array('I', [4])],
#               [3436, array('I', [3])],
#               [3448, array('I', [0])],
#               [3470, array('I', [4])],
#               [3471, array('I', [11])],
#               [3479, array('I', [4])],
#               [3488, array('I', [17])],
#               [3492, array('I', [10])],
#               [3507, array('I', [8])],
#               [3529, array('I', [16])],
#               [3535, array('I', [1])],
#               [3542, array('I', [3])],
#               [3543, array('I', [0])],
#               [3547, array('I', [2])],
#               [3555, array('I', [6])],
#               [3559, array('I', [4])],
#               [3560, array('I', [3])],
#               [3589, array('I', [4])],
#               [3594, array('I', [5])],
#               [3603, array('I', [12])],
#               [3608, array('I', [12])],
#               [3613, array('I', [4])],
#               [3618, array('I', [1])],
#               [3621, array('I', [24])],
#               [3639, array('I', [0])],
#               [3649, array('I', [2])],
#               [3669, array('I', [6, 18])],
#               [3693, array('I', [9])],
#               [3707, array('I', [15])],
#               [3719, array('I', [4])],
#               [3721, array('I', [13])],
#               [3725, array('I', [14])],
#               [3726, array('I', [4])],
#               [3731, array('I', [3])],
#               [3740, array('I', [12])],
#               [3741, array('I', [9])],
#               [3751, array('I', [3])],
#               [3754, array('I', [5])],
#               [3762, array('I', [4])],
#               [3764, array('I', [3])],
#               [3790, array('I', [16])],
#               [3795, array('I', [5])],
#               [3798, array('I', [4])],
#               [3810, array('I', [11])],
#               [3812, array('I', [13])],
#               [3838, array('I', [0])],
#               [3854, array('I', [11])],
#               [3862, array('I', [6])],
#               [3864, array('I', [18, 20])],
#               [3867, array('I', [0])],
#               [3869, array('I', [3, 5])],
#               [3871, array('I', [2])],
#               [3872, array('I', [6])],
#               [3878, array('I', [19])],
#               [3883, array('I', [7])],
#               [3892, array('I', [13])],
#               [3895, array('I', [0])],
#               [3911, array('I', [4])],
#               [3919, array('I', [6, 12, 15, 17])],
#               [3922, array('I', [0])],
#               [3928, array('I', [4])],
#               [3929, array('I', [8])],
#               [3931, array('I', [14])],
#               [3936, array('I', [7])],
#               [3940, array('I', [6])],
#               [3962, array('I', [0])],
#               [3969, array('I', [9, 15, 19])],
#               [3970, array('I', [5])],
#               [3977, array('I', [21])],
#               [3984, array('I', [0])],
#               [3986, array('I', [1])],
#               [3998, array('I', [6])]],
#              'intend': [[1, array('I', [6])],
#               [227, array('I', [4])],
#               [1884, array('I', [9])],
#               [2613, array('I', [3])],
#               [3729, array('I', [12])]],
#              'conquer': [[1, array('I', [7])], [382, array('I', [3])]],
#              'much': [[1, array('I', [8])],
#               [23, array('I', [3])],
#               [80, array('I', [9])],
#               [445, array('I', [13])],
#               [498, array('I', [0])],
#               [658, array('I', [9])],
#               [859, array('I', [4])],
#               [860, array('I', [16])],
#               [909, array('I', [8])],
#               [1322, array('I', [0])],
#               [1415, array('I', [19])],
#               [1884, array('I', [17])],
#               [1930, array('I', [14])],
#               [2137, array('I', [5])],
#               [3007, array('I', [0])],
#               [3051, array('I', [3])],
#               [3158, array('I', [1])],
#               [3254, array('I', [2])],
#               [3326, array('I', [14])],
#               [3405, array('I', [11])],
#               [3407, array('I', [17])],
#               [3491, array('I', [2])],
#               [3711, array('I', [9])],
#               [3806, array('I', [3])],
#               [3946, array('I', [24])],
#               [3950, array('I', [10])],
#               [3981, array('I', [10])],
#               [4000, array('I', [1])]],
#              'ukrainian': [[1, array('I', [9])],
#               [8, array('I', [8])],
#               [17, array('I', [3])],
#               [21, array('I', [0])],
#               [28, array('I', [9])],
#               [31, array('I', [8])],
#               [32, array('I', [7])],
#               [49, array('I', [7])],
#               [50, array('I', [17])],
#               [63, array('I', [5])],
#               [73, array('I', [6, 8])],
#               [104, array('I', [11])],
#               [111, array('I', [11])],
#               [112, array('I', [9])],
#               [113, array('I', [10])],
#               [122, array('I', [20])],
#               [135, array('I', [11])],
#               [153, array('I', [7])],
#               [155, array('I', [0])],
#               [156, array('I', [18])],
#               [160, array('I', [7, 14])],
#               [165, array('I', [7])],
#               [170, array('I', [3])],
#               [171, array('I', [1])],
#               [175, array('I', [9])],
#               [185, array('I', [0])],
#               [197, array('I', [8])],
#               [198, array('I', [4])],
#               [206, array('I', [0])],
#               [210, array('I', [2])],
#               [213, array('I', [4])],
#               [217, array('I', [1])],
#               [222, array('I', [15])],
#               [223, array('I', [0])],
#               [233, array('I', [11])],
#               [240, array('I', [8])],
#               [248, array('I', [5])],
#               [319, array('I', [0])],
#               [320, array('I', [8])],
#               [334, array('I', [3])],
#               [336, array('I', [1])],
#               [366, array('I', [6])],
#               [368, array('I', [0])],
#               [372, array('I', [11])],
#               [376, array('I', [4])],
#               [378, array('I', [8])],
#               [387, array('I', [9])],
#               [394, array('I', [0])],
#               [399, array('I', [8])],
#               [407, array('I', [9])],
#               [411, array('I', [5])],
#               [414, array('I', [9])],
#               [424, array('I', [0])],
#               [425, array('I', [11])],
#               [437, array('I', [2])],
#               [449, array('I', [0])],
#               [453, array('I', [3])],
#               [467, array('I', [1])],
#               [494, array('I', [0])],
#               [503, array('I', [4])],
#               [508, array('I', [0])],
#               [517, array('I', [6])],
#               [521, array('I', [7])],
#               [522, array('I', [0])],
#               [530, array('I', [2])],
#               [531, array('I', [17])],
#               [532, array('I', [0])],
#               [545, array('I', [0])],
#               [560, array('I', [10])],
#               [563, array('I', [5])],
#               [571, array('I', [0])],
#               [581, array('I', [6, 13, 16])],
#               [592, array('I', [4])],
#               [617, array('I', [0])],
#               [622, array('I', [0])],
#               [633, array('I', [8])],
#               [634, array('I', [4])],
#               [644, array('I', [5])],
#               [671, array('I', [6])],
#               [678, array('I', [0])],
#               [682, array('I', [4])],
#               [719, array('I', [0])],
#               [727, array('I', [0])],
#               [738, array('I', [16])],
#               [765, array('I', [8])],
#               [768, array('I', [4])],
#               [770, array('I', [3])],
#               [773, array('I', [5])],
#               [785, array('I', [2])],
#               [809, array('I', [7])],
#               [848, array('I', [5])],
#               [855, array('I', [0])],
#               [861, array('I', [0])],
#               [865, array('I', [6])],
#               [876, array('I', [5])],
#               [878, array('I', [2])],
#               [879, array('I', [2])],
#               [881, array('I', [19])],
#               [885, array('I', [6])],
#               [888, array('I', [10])],
#               [899, array('I', [4])],
#               [912, array('I', [1])],
#               [917, array('I', [7])],
#               [960, array('I', [3])],
#               [969, array('I', [5])],
#               [979, array('I', [3])],
#               [994, array('I', [0])],
#               [1011, array('I', [2])],
#               [1014, array('I', [11])],
#               [1026, array('I', [18])],
#               [1034, array('I', [0])],
#               [1050, array('I', [2])],
#               [1079, array('I', [5])],
#               [1080, array('I', [1])],
#               [1082, array('I', [0])],
#               [1096, array('I', [5])],
#               [1133, array('I', [6])],
#               [1142, array('I', [0])],
#               [1147, array('I', [0])],
#               [1176, array('I', [8])],
#               [1183, array('I', [13])],
#               [1188, array('I', [0])],
#               [1197, array('I', [0])],
#               [1198, array('I', [5])],
#               [1205, array('I', [3])],
#               [1224, array('I', [4, 8])],
#               [1229, array('I', [0])],
#               [1235, array('I', [0])],
#               [1245, array('I', [0])],
#               [1251, array('I', [1])],
#               [1253, array('I', [1])],
#               [1254, array('I', [1])],
#               [1257, array('I', [4])],
#               [1258, array('I', [0])],
#               [1259, array('I', [3, 10])],
#               [1277, array('I', [15])],
#               [1287, array('I', [14])],
#               [1290, array('I', [16])],
#               [1291, array('I', [0])],
#               [1309, array('I', [1])],
#               [1316, array('I', [13])],
#               [1335, array('I', [12])],
#               [1368, array('I', [0])],
#               [1383, array('I', [5])],
#               [1393, array('I', [0])],
#               [1399, array('I', [0, 9])],
#               [1423, array('I', [6])],
#               [1450, array('I', [0])],
#               [1454, array('I', [10])],
#               [1462, array('I', [6])],
#               [1466, array('I', [11])],
#               [1471, array('I', [14])],
#               [1483, array('I', [6])],
#               [1489, array('I', [4])],
#               [1491, array('I', [6])],
#               [1512, array('I', [3])],
#               [1534, array('I', [4])],
#               [1539, array('I', [0, 16])],
#               [1552, array('I', [3])],
#               [1553, array('I', [2])],
#               [1560, array('I', [0])],
#               [1561, array('I', [15])],
#               [1568, array('I', [0])],
#               [1584, array('I', [0])],
#               [1590, array('I', [0])],
#               [1591, array('I', [3])],
#               [1602, array('I', [4])],
#               [1647, array('I', [6])],
#               [1675, array('I', [3])],
#               [1676, array('I', [5])],
#               [1677, array('I', [10])],
#               [1682, array('I', [4])],
#               [1693, array('I', [5])],
#               [1695, array('I', [4])],
#               [1699, array('I', [17])],
#               [1735, array('I', [8])],
#               [1738, array('I', [4])],
#               [1740, array('I', [3])],
#               [1741, array('I', [20])],
#               [1745, array('I', [5])],
#               [1748, array('I', [0])],
#               [1833, array('I', [3])],
#               [1857, array('I', [0])],
#               [1865, array('I', [7])],
#               [1872, array('I', [0])],
#               [1893, array('I', [8])],
#               [1902, array('I', [3])],
#               [1912, array('I', [0])],
#               [1928, array('I', [12])],
#               [1954, array('I', [14])],
#               [1955, array('I', [6])],
#               [1959, array('I', [7])],
#               [1970, array('I', [11])],
#               [1973, array('I', [0])],
#               [1975, array('I', [0])],
#               [1977, array('I', [11])],
#               [2006, array('I', [5])],
#               [2020, array('I', [0])],
#               [2022, array('I', [5])],
#               [2025, array('I', [10])],
#               [2038, array('I', [0])],
#               [2040, array('I', [3, 5])],
#               [2051, array('I', [8])],
#               [2058, array('I', [6])],
#               [2061, array('I', [3])],
#               [2069, array('I', [3])],
#               [2084, array('I', [0])],
# ...
#               [3137, array('I', [11])],
#               [3234, array('I', [10])],
#               [3245, array('I', [3])],
#               [3307, array('I', [14])],
#               [3344, array('I', [8])],
#               [3421, array('I', [6])],
#               [3437, array('I', [17])],
#               [3439, array('I', [7])],
#               [3622, array('I', [10])],
#               [3747, array('I', [6])],
#               [3864, array('I', [6])],
#               [3913, array('I', [8])],
#               [3924, array('I', [8])],
#               [3958, array('I', [1])]],
#              'conor': [[110, array('I', [20, 24])]],
#              'gallagherseptemb': [[110, array('I', [21])]],
#              '2022': [[110, array('I', [23])],
#               [172, array('I', [15])],
#               [276, array('I', [9])],
#               [339, array('I', [4])],
#               [345, array('I', [6])],
#               [394, array('I', [8])],
#               [398, array('I', [9])],
#               [404, array('I', [13])],
#               [415, array('I', [14])],
#               [417, array('I', [10])],
#               [423, array('I', [19])],
#               [432, array('I', [8])],
#               [442, array('I', [19])],
#               [458, array('I', [11])],
#               [461, array('I', [9])],
#               [471, array('I', [5])],
#               [476, array('I', [6])],
#               [478, array('I', [6])],
#               [484, array('I', [4])],
#               [487, array('I', [4])],
#               [511, array('I', [13])],
#               [525, array('I', [13])],
#               [574, array('I', [13])],
#               [749, array('I', [9])],
#               [938, array('I', [22])],
#               [939, array('I', [2])],
#               [954, array('I', [9])],
#               [972, array('I', [15])],
#               [982, array('I', [15])],
#               [1005, array('I', [5])],
#               [1008, array('I', [23])],
#               [1080, array('I', [7])],
#               [1137, array('I', [4])],
#               [1173, array('I', [6])],
#               [1246, array('I', [4])],
#               [1250, array('I', [6])],
#               [1269, array('I', [3])],
#               [1292, array('I', [8])],
#               [1309, array('I', [18])],
#               [1367, array('I', [8])],
#               [1407, array('I', [9])],
#               [1437, array('I', [4])],
#               [1468, array('I', [7])],
#               [1470, array('I', [1])],
#               [1609, array('I', [8])],
#               [1714, array('I', [9])],
#               [1820, array('I', [9])],
#               [1907, array('I', [8])],
#               [1909, array('I', [9])],
#               [1911, array('I', [2])],
#               [1920, array('I', [12])],
#               [1935, array('I', [7])],
#               [1938, array('I', [12])],
#               [1993, array('I', [5])],
#               [2000, array('I', [7])],
#               [2015, array('I', [11])],
#               [2066, array('I', [5])],
#               [2070, array('I', [4])],
#               [2095, array('I', [14])],
#               [2096, array('I', [14])],
#               [2177, array('I', [10])],
#               [2210, array('I', [13])],
#               [2211, array('I', [8, 13])],
#               [2223, array('I', [10])],
#               [2304, array('I', [10])],
#               [2386, array('I', [8])],
#               [2420, array('I', [9])],
#               [2534, array('I', [7])],
#               [2572, array('I', [9])],
#               [2812, array('I', [7])],
#               [2813, array('I', [10])],
#               [2907, array('I', [6])],
#               [2946, array('I', [13])],
#               [2982, array('I', [25])],
#               [3064, array('I', [4])],
#               [3107, array('I', [12])],
#               [3132, array('I', [14, 22])],
#               [3145, array('I', [8])],
#               [3185, array('I', [7])],
#               [3298, array('I', [14])],
#               [3311, array('I', [8])],
#               [3327, array('I', [16])],
#               [3400, array('I', [8])],
#               [3458, array('I', [14])],
#               [3459, array('I', [14])],
#               [3651, array('I', [6])],
#               [3714, array('I', [7])],
#               [3865, array('I', [9])],
#               [3978, array('I', [2])],
#               [3999, array('I', [4])]],
#              'gallagh': [[110, array('I', [25])]],
#              'encircl': [[111, array('I', [1])],
#               [232, array('I', [4])],
#               [368, array('I', [3])],
#               [475, array('I', [2])],
#               [492, array('I', [8])],
#               [538, array('I', [6])],
#               [540, array('I', [5])],
#               [573, array('I', [0])],
#               [669, array('I', [5])],
#               [735, array('I', [20])],
#               [776, array('I', [6])],
#               [782, array('I', [14])],
#               [799, array('I', [13])],
#               [806, array('I', [9])],
#               [812, array('I', [6])],
#               [820, array('I', [6])],
#               [822, array('I', [12])],
#               [828, array('I', [12])],
#               [856, array('I', [9])],
#               [890, array('I', [5, 11])],
#               [906, array('I', [8])],
#               [1067, array('I', [9])],
#               [1118, array('I', [4])],
#               [1131, array('I', [14])],
#               [1141, array('I', [4])],
#               [1178, array('I', [11])],
#               [1194, array('I', [3, 18])],
#               [1217, array('I', [9])],
#               [1244, array('I', [7])],
#               [1361, array('I', [10])],
#               [1424, array('I', [6])],
#               [1572, array('I', [8])],
#               [1676, array('I', [2])],
#               [1694, array('I', [8])],
#               [1697, array('I', [4])],
#               [1837, array('I', [20])],
#               [1900, array('I', [8])],
#               [1995, array('I', [8])],
#               [2020, array('I', [4])],
#               [2466, array('I', [3])],
#               [2823, array('I', [3])],
#               [3118, array('I', [1])],
#               [3200, array('I', [4])],
#               [3601, array('I', [8])],
#               [3775, array('I', [6])],
#               [3824, array('I', [2])],
#               [3915, array('I', [10])],
#               [3966, array('I', [5])]],
#              'https//tco/umebhv4rnv': [[111, array('I', [3])]],
#              'setback': [[111, array('I', [6])], [463, array('I', [15])]],
#              '#lysychansk': [[111, array('I', [13])]],
#              'largest': [[111, array('I', [15])],
#               [1130, array('I', [10])],
#               [1198, array('I', [7])],
#               [2032, array('I', [15])],
#               [2119, array('I', [16])],
#               [2907, array('I', [1])],
#               [3707, array('I', [1])]],
#              'citi': [[111, array('I', [16])],
#               [329, array('I', [10])],
#               [539, array('I', [9])],
#               [556, array('I', [8])],
#               [573, array('I', [3])],
#               [741, array('I', [7, 13])],
#               [846, array('I', [5])],
#               [919, array('I', [7])],
#               [962, array('I', [1])],
#               [1188, array('I', [14])],
#               [1290, array('I', [17])],
#               [1307, array('I', [20])],
#               [1315, array('I', [9])],
#               [1382, array('I', [19])],
#               [1402, array('I', [6])],
#               [1433, array('I', [4])],
#               [1447, array('I', [15])],
#               [1449, array('I', [16])],
#               [1467, array('I', [12])],
#               [1539, array('I', [1, 14])],
#               [1560, array('I', [3])],
#               [1566, array('I', [1])],
#               [1568, array('I', [3])],
#               [1572, array('I', [10])],
#               [1584, array('I', [4])],
#               [1673, array('I', [5])],
#               [1690, array('I', [2])],
#               [1694, array('I', [10])],
#               [1829, array('I', [7])],
#               [1883, array('I', [5])],
#               [1900, array('I', [10])],
#               [1904, array('I', [3])],
#               [1930, array('I', [10])],
#               [1978, array('I', [12, 14])],
#               [1995, array('I', [10])],
#               [2069, array('I', [4, 7])],
#               [2161, array('I', [3])],
#               [2205, array('I', [13])],
#               [2216, array('I', [7])],
#               [2277, array('I', [10])],
#               [2319, array('I', [21])],
#               [2347, array('I', [22])],
#               [2350, array('I', [14])],
#               [2351, array('I', [14])],
#               [2352, array('I', [14])],
#               [2437, array('I', [11])],
#               [2483, array('I', [19])],
#               [2557, array('I', [4])],
#               [2639, array('I', [2])],
#               [2683, array('I', [13])],
#               [2685, array('I', [14])],
#               [2713, array('I', [1])],
#               [2749, array('I', [3])],
#               [2772, array('I', [11])],
#               [2844, array('I', [1, 8])],
#               [2925, array('I', [3])],
#               [2961, array('I', [12])],
#               [3014, array('I', [2])],
#               [3257, array('I', [0])],
#               [3267, array('I', [3])],
#               [3275, array('I', [2])],
#               [3309, array('I', [12])],
#               [3320, array('I', [1])],
#               [3328, array('I', [6])],
#               [3642, array('I', [23])]],
#              'earli': [[111, array('I', [19])],
#               [959, array('I', [8])],
#               [1023, array('I', [9])],
#               [1904, array('I', [12])],
#               [3883, array('I', [0])]],
#              'invas': [[111, array('I', [20])],
#               [170, array('I', [17])],
#               [260, array('I', [6])],
#               [276, array('I', [11])],
#               [427, array('I', [8])],
#               [471, array('I', [1])],
#               [473, array('I', [8])],
#               [718, array('I', [4])],
#               [749, array('I', [11])],
#               [750, array('I', [10])],
#               [756, array('I', [6])],
#               [762, array('I', [8])],
#               [813, array('I', [5])],
#               [883, array('I', [12])],
#               [1015, array('I', [7])],
#               [1029, array('I', [1])],
#               [1041, array('I', [5])],
#               [1348, array('I', [16])],
#               [1419, array('I', [19])],
#               [1639, array('I', [4])],
#               [1714, array('I', [11])],
#               [1716, array('I', [10])],
#               [1724, array('I', [6])],
#               [1733, array('I', [8])],
#               [1766, array('I', [7])],
#               [1909, array('I', [11])],
#               [1954, array('I', [1])],
#               [1955, array('I', [11])],
#               [2145, array('I', [14])],
#               [2401, array('I', [3])],
#               [2419, array('I', [10])],
#               [2420, array('I', [11])],
#               [2467, array('I', [3])],
#               [2540, array('I', [6])],
#               [2545, array('I', [6])],
#               [2572, array('I', [11])],
#               [2573, array('I', [10])],
#               [2581, array('I', [6])],
#               [2590, array('I', [8])],
#               [2601, array('I', [20])],
#               [2626, array('I', [4])],
#               [2692, array('I', [18])],
#               [2693, array('I', [10])],
#               [2759, array('I', [3])],
#               [2760, array('I', [3])],
#               [2808, array('I', [3])],
#               [2812, array('I', [9])],
#               [2951, array('I', [4])],
#               [2960, array('I', [6])],
#               [3185, array('I', [9])],
#               [3204, array('I', [11])],
#               [3313, array('I', [10])],
#               [3360, array('I', [1])],
#               [3405, array('I', [9])],
#               [3511, array('I', [9])],
#               [3549, array('I', [4])],
#               [3559, array('I', [6])],
#               [3613, array('I', [1])],
#               [3682, array('I', [9])],
#               [3922, array('I', [23])],
#               [3990, array('I', [15])]],
#              'src': [[111, array('I', [23])]],
#              '@thestudyofwar': [[111, array('I', [24])],
#               [562, array('I', [4])],
#               [1384, array('I', [7])],
#               [1609, array('I', [10])],
#               [2445, array('I', [4])],
#               [2792, array('I', [7])],
#               [3145, array('I', [10])],
#               [3763, array('I', [1])]],
#              '@nytgraph': [[111, array('I', [26])]],
#              'https//tco/ylo9pdaljx': [[111, array('I', [27])]],
#              'european': [[112, array('I', [0])],
#               [238, array('I', [4])],
#               [305, array('I', [7])],
#               [340, array('I', [11])],
#               [490, array('I', [2])],
#               [575, array('I', [6])],
#               [980, array('I', [9])],
#               [1013, array('I', [2])],
#               [1031, array('I', [5])],
#               [1048, array('I', [3])],
#               [1086, array('I', [4])],
#               [1293, array('I', [0])],
#               [1630, array('I', [17])],
#               [1670, array('I', [11])],
#               [1856, array('I', [11])],
#               [1943, array('I', [4])],
#               [2154, array('I', [10])],
#               [2156, array('I', [10])],
#               [2284, array('I', [1])],
#               [2336, array('I', [10])],
#               [2390, array('I', [6])],
#               [2568, array('I', [0])],
#               [2588, array('I', [1])],
#               [2761, array('I', [0])],
#               [2817, array('I', [0])],
#               [2862, array('I', [15])],
#               [3011, array('I', [2])],
#               [3137, array('I', [2])],
#               [3254, array('I', [3])],
#               [3344, array('I', [2])],
#               [3486, array('I', [3])],
#               [3504, array('I', [2])],
#               [3517, array('I', [3])],
#               [3940, array('I', [0])]],
#              'extern': [[112, array('I', [1])]],
#              'servic': [[112, array('I', [3])],
#               [507, array('I', [14])],
#               [989, array('I', [4])],
#               [990, array('I', [21])],
#               [1107, array('I', [10])],
#               [1111, array('I', [10])],
#               [1113, array('I', [10])],
#               [1276, array('I', [16])],
#               [1978, array('I', [9, 24])],
#               [2369, array('I', [3])],
#               [2381, array('I', [20])],
#               [2659, array('I', [1])],
#               [2701, array('I', [6])],
#               [2750, array('I', [18])],
#               [2862, array('I', [17])],
#               [2937, array('I', [15])],
#               [2978, array('I', [7])],
#               [3385, array('I', [1])],
#               [3795, array('I', [3])],
#               [3869, array('I', [15])],
#               [3972, array('I', [17])]],
#              'independ': [[112, array('I', [7])],
#               [122, array('I', [14])],
#               [281, array('I', [11])],
#               [547, array('I', [2])],
#               [612, array('I', [13])],
#               [634, array('I', [9])],
#               [1375, array('I', [5])],
#               [1473, array('I', [10])],
#               [1502, array('I', [7])],
#               [1593, array('I', [9])],
#               [1691, array('I', [11])],
#               [1699, array('I', [9])],
#               [1865, array('I', [5])],
#               [1893, array('I', [12])],
#               [1911, array('I', [10])],
#               [1920, array('I', [8])],
#               [1938, array('I', [8])],
#               [1950, array('I', [4])],
#               [1959, array('I', [11])],
#               [1961, array('I', [9])],
#               [1972, array('I', [8])],
#               [2214, array('I', [10])],
#               [2294, array('I', [15])],
#               [3222, array('I', [16])],
#               [3365, array('I', [5])],
#               [3714, array('I', [21])],
#               [3902, array('I', [20])],
#               [3963, array('I', [11])]],
#              'kherson…': [[112, array('I', [12])]],
#              'cc': [[112, array('I', [13])], [3111, array('I', [16])]],
#              '@josepborrellf': [[112, array('I', [14])],
#               [778, array('I', [0])],
#               [2915, array('I', [18])]],
#              'https//tco/elrgdytryn': [[112, array('I', [17])]],
#              ...})

# %%
#Create the tf-idf index
start_time = time.time()
num_documents = len(tweets)
index, tf, df, idf = create_index_tfidf(tweets, num_documents)
print("Total time to create the index: {} seconds" .format(np.round(time.time() - start_time, 2)))
# Out:
# Total time to create the index: 241.22 seconds

# %%
def rank_documents(terms, docs, index, idf, tf):
    """
    Perform the ranking of the results of a search based on the tf-idf weights

    Argument:
    terms -- list of query terms
    docs -- list of documents, to rank, matching the query
    index -- inverted index data structure
    idf -- inverted document frequencies
    tf -- term frequencies

    Returns:
    doc_scores -- list of scores
    """

    doc_vectors = defaultdict(lambda: [0] * len(terms)) # Call doc_vectors[k] for a nonexistent key k, the key-value pair (k,[0]*len(terms)) will be automatically added to the dictionary
    query_vector = [0] * len(terms)

    # compute the norm for the query tf
    query_terms_count = collections.Counter(terms)  # get the frequency of each term in the query.

    query_norm = la.norm(list(query_terms_count.values()))

    for termIndex, term in enumerate(terms):  #termIndex is the index of the term in the query
        if term not in index:
            continue

        ## Compute tf*idf(normalize TF as done with documents)
        query_vector[termIndex]=query_terms_count[term]/idf[term] * query_norm

        # Generate doc_vectors for matching docs
        for doc_index, (doc, postings) in enumerate(index[term]):

            #tf[term][0] will contain the tf of the term "term" in the doc 26
            if doc in docs:
                doc_vectors[doc][termIndex] = tf[term][doc_index] * idf[term]
    # Calculate the score of each doc
    # compute the cosine similarity between queyVector and each docVector:

    doc_scores=[[np.dot(curDocVec, query_vector), doc] for doc, curDocVec in doc_vectors.items() ]
    doc_scores.sort(reverse=True)

    return doc_scores

# %%
def search_tf_idf(query, index):
    """
    output is the list of documents that contain any of the query terms.
    So, we will get the list of documents for each query term, and take the union of them.

    Argument:
    query -- name of the query
    index -- created index

    Returns:
    doc_scores -- list of scores
    """
    query = preprocess(query)
    docs = set()
    for term in query:
        try:
            # store in term_docs the ids of the docs that contain "term"
            term_docs=[posting[0] for posting in index[term]]

            # docs = docs Union term_docs
            docs = docs.union(term_docs)
        except:
            #term is not in index
            pass
    docs = list(docs)
    doc_scores = rank_documents(query, docs, index, idf, tf)
    return doc_scores

# %%
#Search tf-idf of query 1
query1 = "Zelenski"
ranked_docs1 = search_tf_idf(query1, index)
top = 20

print("\n======================\nTop {} results out of {} for the query '{}':\n".format(top, len(ranked_docs1), query1))
for _, d_id in ranked_docs1[:top]:
        print("tweet id = {} - tweet: {}".format(d_id, tweets[d_id-1]["url"]))
# Out:
# ======================
# Top 20 results out of 36 for the query 'Zelenski':
#
# tweet id = 451 - tweet: https://twitter.com/Militarylandnet/status/1575855193547165696
# tweet id = 734 - tweet: https://twitter.com/knittingknots/status/1575823179859333120
# tweet id = 474 - tweet: https://twitter.com/_Nex3_/status/1575851734974578688
# tweet id = 430 - tweet: https://twitter.com/knittingknots/status/1575858809842503680
# tweet id = 408 - tweet: https://twitter.com/NEWS_ALL_TIME/status/1575861873060499456
# tweet id = 3271 - tweet: https://twitter.com/knittingknots/status/1575255448818696192
# tweet id = 447 - tweet: https://twitter.com/Magnifyingglas_/status/1575855639011549184
# tweet id = 3270 - tweet: https://twitter.com/knittingknots/status/1575255530154737664
# tweet id = 2784 - tweet: https://twitter.com/AlbaneseAl/status/1575405656772935680
# tweet id = 2782 - tweet: https://twitter.com/AGCsegreteria/status/1575405725936934912
# tweet id = 2781 - tweet: https://twitter.com/pka71/status/1575405776260268032
# tweet id = 411 - tweet: https://twitter.com/knittingknots/status/1575861425133981696
# tweet id = 287 - tweet: https://twitter.com/Shadi_Alkasim/status/1575885728701026304
# tweet id = 464 - tweet: https://twitter.com/_Nex3_/status/1575853653310976000
# tweet id = 417 - tweet: https://twitter.com/Chronology22/status/1575860740556460032
# tweet id = 101 - tweet: https://twitter.com/knittingknots/status/1575907898500468736
# tweet id = 3506 - tweet: https://twitter.com/Daily_Express/status/1575211259833864192
# tweet id = 343 - tweet: https://twitter.com/knittingknots/status/1575874112077299712
# tweet id = 3087 - tweet: https://twitter.com/slim_swede/status/1575315693905580032
# tweet id = 2078 - tweet: https://twitter.com/G700Sway/status/1575573525024251904

# %%
#Search tf-idf of query 2
query2 = "Crimea"
ranked_docs2 = search_tf_idf(query2, index)
top = 20

print("\n======================\nTop {} results out of {} for the query '{}':\n".format(top, len(ranked_docs2), query2))
for _, d_id in ranked_docs2[:top]:
        print("tweet id = {} - tweet: {}".format(d_id, tweets[d_id-1]["url"]))
# Out:
# ======================
# Top 20 results out of 26 for the query 'Crimea':
#
# tweet id = 3361 - tweet: https://twitter.com/Odessa_Journal/status/1575241438937239552
# tweet id = 106 - tweet: https://twitter.com/anthony51483709/status/1575907497017487360
# tweet id = 1109 - tweet: https://twitter.com/KohnNatan/status/1575793173062127616
# tweet id = 2453 - tweet: https://twitter.com/infussambas/status/1575476108077985792
# tweet id = 3281 - tweet: https://twitter.com/NEWS_ALL_TIME/status/1575253795352809472
# tweet id = 354 - tweet: https://twitter.com/UKikaski/status/1575870743631450112
# tweet id = 3506 - tweet: https://twitter.com/Daily_Express/status/1575211259833864192
# tweet id = 175 - tweet: https://twitter.com/knittingknots/status/1575899953456877568
# tweet id = 59 - tweet: https://twitter.com/K13News/status/1575910964112740352
# tweet id = 2336 - tweet: https://twitter.com/knittingknots/status/1575505128337309696
# tweet id = 3649 - tweet: https://twitter.com/knittingknots/status/1575193723364950016
# tweet id = 350 - tweet: https://twitter.com/NEWS_ALL_TIME/status/1575871168787386368
# tweet id = 3883 - tweet: https://twitter.com/andreleoso/status/1575168930389569536
# tweet id = 462 - tweet: https://twitter.com/UKikaski/status/1575854089707335680
# tweet id = 2533 - tweet: https://twitter.com/agrusyvno/status/1575463145610559488
# tweet id = 2131 - tweet: https://twitter.com/ArtemZhuk2/status/1575553822264819712
# tweet id = 2197 - tweet: https://twitter.com/DarwinBedford/status/1575538366179057664
# tweet id = 456 - tweet: https://twitter.com/FreeCiviliansUA/status/1575854630592217088
# tweet id = 170 - tweet: https://twitter.com/NBRnews/status/1575900221141241856
# tweet id = 3922 - tweet: https://twitter.com/FCU_Ukraine/status/1575162775915069440

# %%
#Search tf-idf of query 3
query3 = "Civilians"
ranked_docs3 = search_tf_idf(query3, index)
top = 20

print("\n======================\nTop {} results out of {} for the query '{}':\n".format(top, len(ranked_docs3), query3))
for _, d_id in ranked_docs3[:top]:
        print("tweet id = {} - tweet: {}".format(d_id, tweets[d_id-1]["url"]))
# Out:
# ======================
# Top 20 results out of 88 for the query 'Civilians':
#
# tweet id = 778 - tweet: https://twitter.com/iduxking/status/1575821079590772736
# tweet id = 3853 - tweet: https://twitter.com/K13News/status/1575174008219504640
# tweet id = 908 - tweet: https://twitter.com/WeAreFromUA/status/1575811723293884416
# tweet id = 1120 - tweet: https://twitter.com/MxmLurie/status/1575791448431030272
# tweet id = 1110 - tweet: https://twitter.com/oimmao/status/1575793139595427840
# tweet id = 878 - tweet: https://twitter.com/LynBank25442089/status/1575814023517720576
# tweet id = 774 - tweet: https://twitter.com/iduxking/status/1575821309937860608
# tweet id = 725 - tweet: https://twitter.com/obtener/status/1575823647909941248
# tweet id = 3134 - tweet: https://twitter.com/knittingknots/status/1575301220390129664
# tweet id = 1917 - tweet: https://twitter.com/KolbasenkOleg/status/1575612804647854080
# tweet id = 3593 - tweet: https://twitter.com/knittingknots/status/1575201082279862272
# tweet id = 1908 - tweet: https://twitter.com/metamate_/status/1575614117704237056
# tweet id = 1174 - tweet: https://twitter.com/theSundaily/status/1575786511978885120
# tweet id = 733 - tweet: https://twitter.com/raybrya/status/1575823202294669312
# tweet id = 2315 - tweet: https://twitter.com/infussambas/status/1575510406852120576
# tweet id = 1350 - tweet: https://twitter.com/Annna_ukraine/status/1575750282541412352
# tweet id = 1040 - tweet: https://twitter.com/MoRaY1959/status/1575798982735204352
# tweet id = 2380 - tweet: https://twitter.com/NEWS_ALL_TIME/status/1575489284312014848
# tweet id = 1679 - tweet: https://twitter.com/Suspended_Acct/status/1575648016060805120
# tweet id = 1204 - tweet: https://twitter.com/WeAreProtestors/status/1575781113624088576

# %%
#Search tf-idf of query 4
query4 = "NATO"
ranked_docs4 = search_tf_idf(query4, index)
top = 20

print("\n======================\nTop {} results out of {} for the query '{}':\n".format(top, len(ranked_docs4), query4))
for _, d_id in ranked_docs4[:top]:
        print("tweet id = {} - tweet: {}".format(d_id, tweets[d_id-1]["url"]))
# Out:
# ======================
# Top 20 results out of 121 for the query 'NATO':
#
# tweet id = 183 - tweet: https://twitter.com/NewsZapper/status/1575899185202724864
# tweet id = 176 - tweet: https://twitter.com/chronosome/status/1575899801933185024
# tweet id = 2545 - tweet: https://twitter.com/LynBank25442089/status/1575462118475939840
# tweet id = 2540 - tweet: https://twitter.com/LynBank25442089/status/1575462473058205696
# tweet id = 1827 - tweet: https://twitter.com/Javelinzz/status/1575629399151370240
# tweet id = 83 - tweet: https://twitter.com/elevotv/status/1575909051380432896
# tweet id = 3489 - tweet: https://twitter.com/GabeZZOZZ/status/1575213861359480832
# tweet id = 1506 - tweet: https://twitter.com/Jimwolfie1/status/1575692255612248064
# tweet id = 3483 - tweet: https://twitter.com/nextgenwarss/status/1575215168422023168
# tweet id = 54 - tweet: https://twitter.com/TrimiA98/status/1575911455806742528
# tweet id = 800 - tweet: https://twitter.com/Ak1nc1Turk1071/status/1575819273078906880
# tweet id = 784 - tweet: https://twitter.com/jasgreeny/status/1575820535619280896
# tweet id = 451 - tweet: https://twitter.com/Militarylandnet/status/1575855193547165696
# tweet id = 3535 - tweet: https://twitter.com/NeoLiberalc/status/1575205423027613696
# tweet id = 3379 - tweet: https://twitter.com/PumpingAlpha/status/1575239165557370880
# tweet id = 474 - tweet: https://twitter.com/_Nex3_/status/1575851734974578688
# tweet id = 430 - tweet: https://twitter.com/knittingknots/status/1575858809842503680
# tweet id = 409 - tweet: https://twitter.com/SGNewsAlerts/status/1575861833025478656
# tweet id = 324 - tweet: https://twitter.com/_Nex3_/status/1575879420300390400
# tweet id = 205 - tweet: https://twitter.com/NewsZapper/status/1575896967229870080

# %%
#Search tf-idf of query 5
query5 = "Negotiations"
ranked_docs5 = search_tf_idf(query5, index)
top = 20

print("\n======================\nTop {} results out of {} for the query '{}':\n".format(top, len(ranked_docs5), query5))
for _, d_id in ranked_docs5[:top]:
        print("tweet id = {} - tweet: {}".format(d_id, tweets[d_id-1]["url"]))
# Out:
# ======================
# Top 20 results out of 37 for the query 'Negotiations':
#
# tweet id = 1218 - tweet: https://twitter.com/PatilSushmit/status/1575776384324374528
# tweet id = 699 - tweet: https://twitter.com/Amannatt/status/1575825005291524096
# tweet id = 515 - tweet: https://twitter.com/u_me_reality/status/1575845160134451200
# tweet id = 24 - tweet: https://twitter.com/Shadi_Alkasim/status/1575914711388139520
# tweet id = 3305 - tweet: https://twitter.com/MaoistRebelNews/status/1575247684621012992
# tweet id = 687 - tweet: https://twitter.com/NEWS_ALL_TIME/status/1575825370061844480
# tweet id = 616 - tweet: https://twitter.com/infussambas/status/1575830518503198720
# tweet id = 583 - tweet: https://twitter.com/SGNewsAlerts/status/1575835852152147968
# tweet id = 349 - tweet: https://twitter.com/UKikaski/status/1575871713317105664
# tweet id = 3123 - tweet: https://twitter.com/GranataLLC/status/1575304304004562944
# tweet id = 659 - tweet: https://twitter.com/_Nex3_/status/1575827009048956928
# tweet id = 417 - tweet: https://twitter.com/Chronology22/status/1575860740556460032
# tweet id = 380 - tweet: https://twitter.com/knittingknots/status/1575866621050073088
# tweet id = 1657 - tweet: https://twitter.com/Odessa_Journal/status/1575653403417628672
# tweet id = 605 - tweet: https://twitter.com/infussambas/status/1575832319206002688
# tweet id = 364 - tweet: https://twitter.com/NEWS_ALL_TIME/status/1575868931067113472
# tweet id = 3067 - tweet: https://twitter.com/ScottTMcLarty/status/1575324772199710720
# tweet id = 3795 - tweet: https://twitter.com/LynxLV/status/1575179206740189184
# tweet id = 3764 - tweet: https://twitter.com/BlogUkraine/status/1575182093973233664
# tweet id = 2145 - tweet: https://twitter.com/crypticvalentin/status/1575550410089238528

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### With the given queries

# %%
#Load the evaluation_gt.csv
evaluation_df = pd.read_csv("/content/drive/Shareddrives/IRWA/IRWA_data_2023/Evaluation_gt.csv")

#Get the ids of the doc in evaluation
sample_ids = evaluation_df["doc"]
evaluation_df.head()
print(len(np.array(sample_ids)))
# Out:
# 60

# %%
#Take the tweets sample that appears in the evaluation file
tweet_sample = [tweet for tweet in tweets if tweet['id'] in np.array(sample_ids)]
len(tweet_sample)
# Out:
# 59

# %% [markdown]
# There is one less doc in tweet_sample since DOC ID 3478 appears for two different queries.

# %%
#Define the 3 queries
queries = {
    "Q1": "tanks in Kharkiv",
    "Q2": "Nord Stream pipeline",
    "Q3": "annexation of crimea"
}

# %%
def take_evaluation_documents(evaluation_df, query, tweets):
    """
    Parameters
    ----------
    evaluation_df: The evaluation document with the doc_ids, the query_ids and the labels
    query: The query_id we want to evaluate.
    tweets : The tweets sample.

    Returns
    -------
    the doc_ids with their label : dict
    the tweets to be scored : array

    """
    query_evaluation_docs = {}

    for doc_id, query_id, label in zip(evaluation_df["doc"], evaluation_df["query_id"], evaluation_df["label"]):

        #Add the documents that are labeled for that query
        if query_id == query:
            query_evaluation_docs[doc_id] = label

        else:
            #Also add the documents that are relevant to other queries
            if label == 1:
                query_evaluation_docs[doc_id] = 0

    query_evaluation_tweets = [tweet for tweet in tweets if tweet["id"] in query_evaluation_docs]

    return query_evaluation_docs, query_evaluation_tweets

# %%
def predicted_scores(query_evaluation_docs, query, index):
    """
    Parameters
    ----------
    query_evaluation_docs: The ids of the documents to be evaluated
    query: The query_id we want to evaluate.
    index : The tf-idf index.

    Returns
    -------
    predictes scores : array

    """
    search_scores = search_tf_idf(queries[query], index)
    #scores = {f"doc_{doc_scores[1]}": doc_scores[0] for doc_scores in search_scores if f"doc_{doc_scores[1]}" in query_evaluation_docs}

    scores = {doc_id: 0.0 for doc_id in query_evaluation_docs}

    for doc_id in query_evaluation_docs:
        for doc_score in search_scores:
            if(f"doc_{doc_score[1]}" == doc_id):
                scores[doc_id] = doc_score[0]
    return scores

# %%
# Information need 1: What is the discussion regarding a tank in Kharkiv?
ground_truths_Q1, my_tweets_Q1 = take_evaluation_documents(evaluation_df, "Q1", tweet_sample)
predicted_values_Q1 = predicted_scores(ground_truths_Q1, "Q1", index)
predicted_values_Q1
# Out:
# {'doc_2052': 0.0,
#  'doc_164': 0.0,
#  'doc_411': 0.0,
#  'doc_1805': 0.0,
#  'doc_3442': 0.0,
#  'doc_2657': 0.0,
#  'doc_1534': 0.0,
#  'doc_383': 0.0,
#  'doc_1618': 0.0,
#  'doc_63': 0.0,
#  'doc_1452': 0.0,
#  'doc_2908': 0.0,
#  'doc_618': 0.0,
#  'doc_2677': 0.0,
#  'doc_489': 0.0,
#  'doc_110': 0.0,
#  'doc_3439': 0.0,
#  'doc_3137': 0.0,
#  'doc_3913': 0.0,
#  'doc_2696': 0.0,
#  'doc_2234': 0.8943486568447452,
#  'doc_2656': 0.35355339059327373,
#  'doc_3709': 0.40828345545711253,
#  'doc_592': 0.6858935777509511,
#  'doc_3556': 0.27732727958136394,
#  'doc_2586': 0.2722361107568208,
#  'doc_2701': 0.7071067811865475,
#  'doc_3478': 0.4418003168853549,
#  'doc_2956': 0.34294678887547553,
#  'doc_3552': 0.26728636328851496,
#  'doc_1336': 0.5000659156551265,
#  'doc_2295': 0.39230284220229655,
#  'doc_2176': 0.4713573803389525,
#  'doc_2488': 0.0,
#  'doc_1669': 0.0,
#  'doc_1953': 0.0,
#  'doc_1641': 0.0,
#  'doc_637': 0.0,
#  'doc_885': 0.0,
#  'doc_174': 0.0}

# %%
# Information need 2: What discussions are there about the Nord Stream pipeline?
ground_truths_Q2, my_tweets_Q2 = take_evaluation_documents(evaluation_df, "Q2", tweet_sample)
predicted_values_Q2 = predicted_scores(ground_truths_Q2, "Q2", index)
predicted_values_Q2
# Out:
# {'doc_2052': 0.0,
#  'doc_164': 0.0,
#  'doc_411': 0.0,
#  'doc_1805': 0.0,
#  'doc_3442': 0.0,
#  'doc_2657': 0.0,
#  'doc_1534': 0.0,
#  'doc_383': 0.0,
#  'doc_1618': 0.0,
#  'doc_63': 0.0,
#  'doc_1452': 1.4852335674903123,
#  'doc_2908': 1.698275816821284,
#  'doc_618': 1.5666399554460493,
#  'doc_2677': 1.299038105676658,
#  'doc_489': 1.224733126031953,
#  'doc_110': 0.8911401404941874,
#  'doc_3439': 0.9259543617263216,
#  'doc_3137': 1.0605347094744235,
#  'doc_3913': 1.1078196965210538,
#  'doc_2696': 0.8911401404941874,
#  'doc_1933': 0.0,
#  'doc_3326': 0.0,
#  'doc_1095': 0.0,
#  'doc_2164': 0.0,
#  'doc_3146': 0.0,
#  'doc_3297': 0.0,
#  'doc_243': 0.0,
#  'doc_477': 0.0,
#  'doc_2457': 0.0,
#  'doc_3967': 0.0,
#  'doc_2234': 0.0,
#  'doc_2656': 0.0,
#  'doc_3709': 0.0,
#  'doc_592': 0.0,
#  'doc_3556': 0.0,
#  'doc_2586': 0.0,
#  'doc_2701': 0.0,
#  'doc_3478': 0.0,
#  'doc_2956': 0.0,
#  'doc_3552': 0.0}

# %%
# Information need 3: What is being said about the annexation of territories by Russia?
ground_truths_Q3, my_tweets_Q3 = take_evaluation_documents(evaluation_df, "Q3", tweet_sample)
predicted_values_Q3 = predicted_scores(ground_truths_Q3, "Q3", index)
predicted_values_Q3
# Out:
# {'doc_2052': 0.37801928522232825,
#  'doc_164': 0.40828345545711253,
#  'doc_411': 0.39230284220229655,
#  'doc_1805': 0.324420591208388,
#  'doc_3442': 0.37801928522232825,
#  'doc_2657': 0.5345727265770299,
#  'doc_1534': 0.3535533905932738,
#  'doc_383': 0.39230284220229655,
#  'doc_1618': 0.3535533905932738,
#  'doc_63': 0.3015103314979439,
#  'doc_3803': 0.0,
#  'doc_1069': 0.0,
#  'doc_2852': 0.0,
#  'doc_3445': 0.0,
#  'doc_421': 0.0,
#  'doc_3478': 0.0,
#  'doc_3705': 0.0,
#  'doc_3422': 0.0,
#  'doc_650': 0.0,
#  'doc_2442': 0.0,
#  'doc_1452': 0.0,
#  'doc_2908': 0.0,
#  'doc_618': 0.0,
#  'doc_2677': 0.0,
#  'doc_489': 0.0,
#  'doc_110': 0.0,
#  'doc_3439': 0.0,
#  'doc_3137': 0.0,
#  'doc_3913': 0.0,
#  'doc_2696': 0.0,
#  'doc_2234': 0.0,
#  'doc_2656': 0.0,
#  'doc_3709': 0.0,
#  'doc_592': 0.0,
#  'doc_3556': 0.0,
#  'doc_2586': 0.0,
#  'doc_2701': 0.0,
#  'doc_2956': 0.0,
#  'doc_3552': 0.0}

# %% [markdown]
# Now we can apply the different metrics

# %% [markdown]
# ######Precision@K (P@K)

# %%
def precision_at_k(doc_score, y_score, k):
    """
    Parameters
    ----------
    doc_score: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    precision @k : float

    """
    order = np.argsort(y_score)[::-1] #order in descending order
    doc_score = np.take(doc_score, order[:k]) #y_true
    relevant = np.sum(doc_score==1) #get num of relevant documents extracted
    return float(relevant) / k

# %%
# Compute Precision@K (P@K) for Q1
print('The precision for query: Tanks in Kharkiv is:\n')
precision_Q1 = precision_at_k(list(ground_truths_Q1.values()), list(predicted_values_Q1.values()), k=10)
print(precision_Q1)
# Out:
# The precision for query: Tanks in Kharkiv is:
#
# 0.7

# %%
# Compute Precision@K (P@K) for Q2
print('The precision for query: Nord Stream pipeline:\n')
precision_Q2 = precision_at_k(list(ground_truths_Q2.values()), list(predicted_values_Q2.values()), k=10)
print(precision_Q2)
# Out:
# The precision for query: Nord Stream pipeline:
#
# 1.0

# %%
# Compute Precision@K (P@K) for Q3
print('The precision for query: Annexation of crimea:\n')
precision_Q3 = precision_at_k(list(ground_truths_Q3.values()), list(predicted_values_Q3.values()), k=10)
print(precision_Q3)
# Out:
# The precision for query: Annexation of crimea:
#
# 1.0

# %% [markdown]
# ######Recall@K (R@K)

# %%
def recall_at_k(doc_score, y_score, k):
    """
    Parameters
    ----------
    doc_score: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    recall @k : float

    """
    order = np.argsort(y_score)[::-1]
    total_relevant = np.sum(doc_score)
    doc_score = np.take(doc_score, order[:k])  # y_true
    relevant = np.sum(doc_score == 1)
    return float(relevant) / total_relevant

# %%
# Compute Recall@K (R@K) for Q1
print('The recall for query: Tanks in Kharkiv is:\n')
recall_Q1 = recall_at_k(list(ground_truths_Q1.values()), list(predicted_values_Q1.values()), k=10)
recall_Q1
# Out:
# The recall for query: Tanks in Kharkiv is:
# 0.7

# %%
# Compute Recall@K (R@K) for Q2
print('The recall for query: Nord Stream pipeline is:\n')
recall_Q2 = recall_at_k(list(ground_truths_Q2.values()), list(predicted_values_Q2.values()), k=10)
recall_Q2
# Out:
# The recall for query: Nord Stream pipeline is:
# 1.0

# %%
# Compute Recall@K (R@K) for Q3
print('The recall for query: Annexation of crimea is:\n')
recall_Q3 = recall_at_k(list(ground_truths_Q3.values()), list(predicted_values_Q3.values()), k=10)
recall_Q3
# Out:
# The recall for query: Annexation of crimea is:
# 1.0

# %% [markdown]
# ######Average Precision@K (P@K)

# %%
def avg_precision_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    average precision @k : float
    """
    gtp = np.sum([score for score in doc_score if score == 1])
    order = np.argsort(y_score)[::-1]
    doc_score = np.take(doc_score, order[:k])
    ## if all documents are not relevant
    if gtp == 0:
        return 0
    n_relevant_at_i = 0
    prec_at_i = 0
    for i in range(len(doc_score)):
        if doc_score[i] == 1:
            n_relevant_at_i += 1
            prec_at_i += n_relevant_at_i / (i + 1)
    return prec_at_i / gtp

# %%
# Compute Average Precision@K (P@K) for Q1
print('The average precision at k of query: Tanks in Kharkiv is:\n')
avg_precision_at_k(list(ground_truths_Q1.values()), list(predicted_values_Q1.values()), k=10)
# Out:
# The average precision at k of query: Tanks in Kharkiv is:
# 0.5747619047619048

# %%
# Compute Average Precision@K (P@K) for Q2
print('The average precision at k of query: Nord Stream pipeline is:\n')
avg_precision_at_k(list(ground_truths_Q2.values()), list(predicted_values_Q2.values()), k=10)
# Out:
# The average precision at k of query: Nord Stream pipeline is:
# 1.0

# %%
# Compute Average Precision@K (P@K) for Q3
print('The average precision at k of query: Annexation of crimea is:\n')
avg_precision_at_k(list(ground_truths_Q3.values()), list(predicted_values_Q3.values()), k=10)
# Out:
# The average precision at k of query: Annexation of crimea is:
# 1.0

# %% [markdown]
# #####F1-Score@K

# %%
def f1_score(precision, recall):
  '''
    Parameters
    ----------
    precision: precision of query
    recall: recall of query

    Returns
    -------
    f1_score : float
  '''
  mult = 2*precision*recall
  sum = precision + recall

  score = mult/sum

  return score

# %%
# Compute F1-Score@K for Q1
print('The f1 score of query: Tanks in Kharkiv is:\n')
f1_score(precision_Q1, recall_Q1)
# Out:
# The f1 score of query: Tanks in Kharkiv is:
# 0.7

# %%
# Compute F1-Score@K for Q2
print('The f1 score of query: Nord Stream pipeline is:\n')
f1_score(precision_Q2, recall_Q2)
# Out:
# The f1 score of query: Nord Stream pipeline is:
# 1.0

# %%
# Compute F1-Score@K for Q3
print('The f1 score of query: Annexation of crimea is:\n')
f1_score(precision_Q3, recall_Q3)
# Out:
# The f1 score of query: Annexation of crimea is:
# 1.0

# %% [markdown]
# #####Mean Average Precision (MAP)

# %%
evaluation_df.head()
# Out:
#         doc query_id  label
# 0  doc_2052       Q3      1
# 1   doc_164       Q3      1
# 2   doc_411       Q3      1
# 3  doc_1805       Q3      1
# 4  doc_3442       Q3      1

# %%
def map_at_k(evaluation_df, queries, index, tweet_sample, k=10):
    """
    Parameters
    ----------
    evaluation_df: search results dataset containing
    queries: list of the queries
    index: the tf-idf index
    tweet_sample: the tweets to use
    k : number of doc to consider

    Returns
    -------
    mean average precision @ k : float
    """
    avp = []
    for q in queries:  # loop over all query id
        current_ground_truths, _ = take_evaluation_documents(evaluation_df, q, tweet_sample)  # select data for current query
        current_scores = predicted_scores(current_ground_truths, q, index)
        avp.append(avg_precision_at_k(list(current_ground_truths.values()), list(current_scores.values()), k))  #append average precision for current query
    return (np.average(avp), avp)  # return mean average precision

# %%
# Compute Mean Average Precision (MAP)
map_at_k(evaluation_df, queries, index, tweet_sample, k=10)
# Out:
# (0.8582539682539684, [0.5747619047619048, 1.0, 1.0])

# %% [markdown]
# #####Mean Reciprocal Rank (MRR)

# %%
def rr_at_k(doc_score, y_score, k=10):
    """
    Parameters
    ----------
    doc_score: Ground truth (true relevance labels).
    y_score: Predicted scores.
    k : number of doc to consider.

    Returns
    -------
    Reciprocal Rank for current query
    """

    order = np.argsort(y_score)[::-1]  # get the list of indexes of the predicted score sorted in descending order.
    doc_score = np.take(doc_score, order[:k])  # sort the actual relevance label of the documents based on predicted score(hint: np.take) and take first k.
    if np.sum(doc_score) == 0:  # if there are not relevant document return 0
        return 0
    return 1 / (np.argmax(doc_score)+1)  # hint: to get the position of the first relevant document use "np.argmax"

# %%
def mrr_at_k(evaluation_df, queries, index, tweet_sample, k=10):
    """
    Parameters
    ----------
    evaluation_df: search results dataset containing
    queries: list of the queries
    index: the tf-idf index
    tweet_sample: the tweets to use
    k : number of doc to consider

    Returns
    -------
    mean Reciprocal Rank @ k : float
    """
    avrr = []
    for q in queries:  # loop over all query id
        current_ground_truths, _ = take_evaluation_documents(evaluation_df, q, tweet_sample)  # select data for current query
        current_scores = predicted_scores(current_ground_truths, q, index)
        avrr.append(rr_at_k(list(current_ground_truths.values()), list(current_scores.values()), k))  #append average precision for current query
    return (np.average(avrr), avrr)  # return mean reciprocal rank

# %%
mrr_at_k(evaluation_df, queries, index, tweet_sample, k=10)
# Out:
# (1.0, [1.0, 1.0, 1.0])

# %% [markdown]
# #####Normalized Discounted Cumulative Gain (NDCG)

# %%
def dcg_at_k(doc_score, y_score, k=10):
    order = np.argsort(y_score)[::-1]  # get the list of indexes of the predicted score sorted in descending order.
    doc_score = np.take(doc_score, order[:k])  # sort the actual relevance label of the documents based on predicted score(hint: np.take) and take first k.
    gain = 2**doc_score - 1  # Compute gain (use formula 7 above)
    discounts = np.log2(np.arange(len(doc_score)) + 2) # Compute denominator
    return np.sum(gain / discounts)  #return dcg@k


def ndcg_at_k(doc_score, y_score, k=10):
    dcg_max = dcg_at_k(doc_score, y_score, k) # Ideal dcg
    if not dcg_max:
        return 0
    return np.round(dcg_at_k(doc_score, y_score, k) / dcg_max, 4) # return ndcg@k

# %%
def mndcg_at_k(evaluation_df, queries, index, tweet_sample, k=10):
    """
    Parameters
    ----------
    evaluation_df: search results dataset containing
    queries: list of the queries
    index: the tf-idf index
    tweet_sample: the tweets to use
    k : number of doc to consider

    Returns
    -------
    mean Normalized Discounted Cumulative Gain @ k : float
    """
    avndcg = []
    for q in queries:  # loop over all query id
        current_ground_truths, _ = take_evaluation_documents(evaluation_df, q, tweet_sample)  # select data for current query
        current_scores = predicted_scores(current_ground_truths, q, index)
        avndcg.append(ndcg_at_k(list(current_ground_truths.values()), list(current_scores.values()), k))  #append average precision for current query
    return (np.average(avndcg), avndcg)  # return mean Normalized Discounted Cumulative Gain

# %%
mndcg_at_k(evaluation_df, queries, index, tweet_sample, k=10)
# Out:
# (1.0, [1.0, 1.0, 1.0])

# %% [markdown]
# ### With our Queries

# %%
#Load the evaluation_gt.csv
evaluation_df = pd.read_csv("/content/drive/Shareddrives/IRWA/IRWA_data_2023/Evaluation_gt2.csv")

#Get the ids of the doc in evaluation
sample_ids = evaluation_df["doc"]
print(len(np.array(sample_ids)))
evaluation_df.head()
# Out:
# 100
#         doc query_id  label
# 0  doc_3506       Q1      1
# 1   doc_430       Q1      1
# 2  doc_3879       Q1      1
# 3   doc_417       Q1      1
# 4   doc_287       Q1      1

# %%
#Define the queries created previously
queries = {
    "Q1": query1,
    "Q2": query2,
    "Q3": query3,
    "Q4": query4,
    "Q5": query5
}

# %%
#Take the tweets sample that appears in the evaluation file
tweet_sample = [tweet for tweet in tweets if tweet['id'] in np.array(sample_ids)]
len(tweet_sample)
# Out:
# 90

# %%
#First query
ground_truths_Q1, my_tweets_Q1 = take_evaluation_documents(evaluation_df, "Q1", tweet_sample)
predicted_values_Q1 = predicted_scores(ground_truths_Q1, "Q1", index)

for gt, pred in zip(ground_truths_Q1.items(), predicted_values_Q1.values()):
    print(f"Ground truth: {gt}  Predicted value: {pred}")
# Out:
# Ground truth: ('doc_3506', 1)  Predicted value: 0.25
# Ground truth: ('doc_430', 1)  Predicted value: 0.3015
# Ground truth: ('doc_3879', 1)  Predicted value: 0.1925
# Ground truth: ('doc_417', 0)  Predicted value: 0.2582
# Ground truth: ('doc_287', 1)  Predicted value: 0.2774
# Ground truth: ('doc_411', 1)  Predicted value: 0.2774
# Ground truth: ('doc_783', 1)  Predicted value: 0.2085
# Ground truth: ('doc_451', 1)  Predicted value: 0.3162
# Ground truth: ('doc_3270', 1)  Predicted value: 0.2774
# Ground truth: ('doc_2781', 1)  Predicted value: 0.2774
# Ground truth: ('doc_61', 0)  Predicted value: 0.0
# Ground truth: ('doc_115', 0)  Predicted value: 0.0
# Ground truth: ('doc_251', 0)  Predicted value: 0.0
# Ground truth: ('doc_499', 0)  Predicted value: 0.0
# Ground truth: ('doc_928', 0)  Predicted value: 0.0
# Ground truth: ('doc_1972', 0)  Predicted value: 0.0
# Ground truth: ('doc_1580', 0)  Predicted value: 0.0
# Ground truth: ('doc_2901', 0)  Predicted value: 0.0
# Ground truth: ('doc_2574', 0)  Predicted value: 0.0
# Ground truth: ('doc_3487', 0)  Predicted value: 0.0
# Ground truth: ('doc_3856', 0)  Predicted value: 0.0
# Ground truth: ('doc_2197', 0)  Predicted value: 0.0
# Ground truth: ('doc_2453', 0)  Predicted value: 0.0
# Ground truth: ('doc_175', 0)  Predicted value: 0.0
# Ground truth: ('doc_3506 ', 0)  Predicted value: 0.0
# Ground truth: ('doc_59', 0)  Predicted value: 0.0
# Ground truth: ('doc_317', 0)  Predicted value: 0.0
# Ground truth: ('doc_321', 0)  Predicted value: 0.0
# Ground truth: ('doc_462', 0)  Predicted value: 0.0
# Ground truth: ('doc_3281 ', 0)  Predicted value: 0.0
# Ground truth: ('doc_1025', 0)  Predicted value: 0.0
# Ground truth: ('doc_1040', 0)  Predicted value: 0.0
# Ground truth: ('doc_1110', 0)  Predicted value: 0.0
# Ground truth: ('doc_67', 0)  Predicted value: 0.0
# Ground truth: ('doc_1204', 0)  Predicted value: 0.0
# Ground truth: ('doc_3235', 0)  Predicted value: 0.0
# Ground truth: ('doc_1316', 0)  Predicted value: 0.0
# Ground truth: ('doc_2473', 0)  Predicted value: 0.0
# Ground truth: ('doc_840', 0)  Predicted value: 0.0
# Ground truth: ('doc_2380', 0)  Predicted value: 0.0
# Ground truth: ('doc_27', 0)  Predicted value: 0.0
# Ground truth: ('doc_3629', 0)  Predicted value: 0.0
# Ground truth: ('doc_54', 0)  Predicted value: 0.0
# Ground truth: ('doc_74', 0)  Predicted value: 0.0
# Ground truth: ('doc_94', 0)  Predicted value: 0.0
# Ground truth: ('doc_99', 0)  Predicted value: 0.0
# Ground truth: ('doc_105', 0)  Predicted value: 0.0
# Ground truth: ('doc_116', 0)  Predicted value: 0.0
# Ground truth: ('doc_153', 0)  Predicted value: 0.0
# Ground truth: ('doc_163', 0)  Predicted value: 0.0
# Ground truth: ('doc_515', 0)  Predicted value: 0.0
# Ground truth: ('doc_1799 ', 0)  Predicted value: 0.0
# Ground truth: ('doc_659 ', 0)  Predicted value: 0.0
# Ground truth: ('doc_3991 ', 0)  Predicted value: 0.0
# Ground truth: ('doc_24 ', 0)  Predicted value: 0.0
# Ground truth: ('doc_415 ', 0)  Predicted value: 0.0
# Ground truth: ('doc_3878 ', 0)  Predicted value: 0.0
# Ground truth: ('doc_41', 0)  Predicted value: 0.0
# Ground truth: ('doc_687', 0)  Predicted value: 0.0

# %%
#Second query
ground_truths_Q2, my_tweets_Q2 = take_evaluation_documents(evaluation_df, "Q2", tweet_sample)
predicted_values_Q2 = predicted_scores(ground_truths_Q2, "Q2", index)

# %%
#Third query
ground_truths_Q3, my_tweets_Q3 = take_evaluation_documents(evaluation_df, "Q3", tweet_sample)
predicted_values_Q3 = predicted_scores(ground_truths_Q3, "Q3", index)

# %%
#Fourth query
ground_truths_Q4, my_tweets_Q4 = take_evaluation_documents(evaluation_df, "Q4", tweet_sample)
predicted_values_Q4 = predicted_scores(ground_truths_Q4, "Q4", index)

# %%
#Fifth query
ground_truths_Q5, my_tweets_Q5 = take_evaluation_documents(evaluation_df, "Q5", tweet_sample)
predicted_values_Q5 = predicted_scores(ground_truths_Q5, "Q5", index)

# %%
ground_truths = {
    "Q1": list(ground_truths_Q1.values()),
    "Q2": list(ground_truths_Q2.values()),
    "Q3": list(ground_truths_Q3.values()),
    "Q4": list(ground_truths_Q4.values()),
    "Q5": list(ground_truths_Q5.values())
}

predicted_values = {
    "Q1": list(predicted_values_Q1.values()),
    "Q2": list(predicted_values_Q2.values()),
    "Q3": list(predicted_values_Q3.values()),
    "Q4": list(predicted_values_Q4.values()),
    "Q5": list(predicted_values_Q5.values())
}

# %% [markdown]
# #### Metrics

# %%
# Compute Precision@K (P@K) for all queries
for k in [3, 5, 10, 20]:
    for q in queries:
        print(f'The precision@{k} for {q} is:')
        precision_current = precision_at_k(ground_truths[q], predicted_values[q], k)
        print(precision_current)
        print()
    print("--"*20)
    print()
# Out:
# The precision@3 for Q1 is:
# 1.0
#
# The precision@3 for Q2 is:
# 0.6666666666666666
#
# The precision@3 for Q3 is:
# 1.0
#
# The precision@3 for Q4 is:
# 0.3333333333333333
#
# The precision@3 for Q5 is:
# 1.0
#
# ----------------------------------------
#
# The precision@5 for Q1 is:
# 1.0
#
# The precision@5 for Q2 is:
# 0.8
#
# The precision@5 for Q3 is:
# 1.0
#
# The precision@5 for Q4 is:
# 0.4
#
# The precision@5 for Q5 is:
# 0.8
#
# ----------------------------------------
#
# The precision@10 for Q1 is:
# 0.9
#
# The precision@10 for Q2 is:
# 0.8
#
# The precision@10 for Q3 is:
# 1.0
#
# The precision@10 for Q4 is:
# 0.7
#
# The precision@10 for Q5 is:
# 0.4
#
# ----------------------------------------
#
# The precision@20 for Q1 is:
# 0.45
#
# The precision@20 for Q2 is:
# 0.45
#
# The precision@20 for Q3 is:
# 0.5
#
# The precision@20 for Q4 is:
# 0.5
#
# The precision@20 for Q5 is:
# 0.2
#
# ----------------------------------------

# %%
# Compute Recall@K (R@K) for all queries
for k in [3, 5, 10, 20]:
    for q in queries:
        print(f'The recall@{k} for {q} is:')
        recall_current = recall_at_k(ground_truths[q], predicted_values[q], k)
        print(recall_current)
        print()
    print("--"*20)
    print()
# Out:
# The recall@3 for Q1 is:
# 0.3333333333333333
#
# The recall@3 for Q2 is:
# 0.2
#
# The recall@3 for Q3 is:
# 0.3
#
# The recall@3 for Q4 is:
# 0.1
#
# The recall@3 for Q5 is:
# 0.3
#
# ----------------------------------------
#
# The recall@5 for Q1 is:
# 0.5555555555555556
#
# The recall@5 for Q2 is:
# 0.4
#
# The recall@5 for Q3 is:
# 0.5
#
# The recall@5 for Q4 is:
# 0.2
#
# The recall@5 for Q5 is:
# 0.4
#
# ----------------------------------------
#
# The recall@10 for Q1 is:
# 1.0
#
# The recall@10 for Q2 is:
# 0.8
#
# The recall@10 for Q3 is:
# 1.0
#
# The recall@10 for Q4 is:
# 0.7
#
# The recall@10 for Q5 is:
# 0.4
#
# ----------------------------------------
#
# The recall@20 for Q1 is:
# 1.0
#
# The recall@20 for Q2 is:
# 0.9
#
# The recall@20 for Q3 is:
# 1.0
#
# The recall@20 for Q4 is:
# 1.0
#
# The recall@20 for Q5 is:
# 0.4
#
# ----------------------------------------

# %%
for k in [3, 5, 10, 20]:
    map = map_at_k(evaluation_df, queries, index, tweet_sample, k)
    for i, q in enumerate(queries):
        print(f'The Average Precision@{k} for {q} is:')
        print(map[1][i])
        print()
    print(f"The Mean Average Precision@{k} is: {map[0]}")
    print()
    print("--"*20)
    print()
# Out:
# The Average Precision@3 for Q1 is:
# 0.3333333333333333
#
# The Average Precision@3 for Q2 is:
# 0.16666666666666666
#
# The Average Precision@3 for Q3 is:
# 0.3
#
# The Average Precision@3 for Q4 is:
# 0.1
#
# The Average Precision@3 for Q5 is:
# 0.3
#
# The Mean Average Precision@3 is: 0.24
#
# ----------------------------------------
#
# The Average Precision@5 for Q1 is:
# 0.5555555555555556
#
# The Average Precision@5 for Q2 is:
# 0.32166666666666666
#
# The Average Precision@5 for Q3 is:
# 0.5
#
# The Average Precision@5 for Q4 is:
# 0.13999999999999999
#
# The Average Precision@5 for Q5 is:
# 0.4
#
# The Mean Average Precision@5 is: 0.3834444444444444
#
# ----------------------------------------
#
# The Average Precision@10 for Q1 is:
# 0.9626543209876544
#
# The Average Precision@10 for Q2 is:
# 0.6377777777777778
#
# The Average Precision@10 for Q3 is:
# 1.0
#
# The Average Precision@10 for Q4 is:
# 0.44630952380952377
#
# The Average Precision@10 for Q5 is:
# 0.4
#
# The Mean Average Precision@10 is: 0.6893483245149911
#
# ----------------------------------------
#
# The Average Precision@20 for Q1 is:
# 0.9626543209876544
#
# The Average Precision@20 for Q2 is:
# 0.6877777777777777
#
# The Average Precision@20 for Q3 is:
# 1.0
#
# The Average Precision@20 for Q4 is:
# 0.6709598734598734
#
# The Average Precision@20 for Q5 is:
# 0.4
#
# The Mean Average Precision@20 is: 0.7442783944450612
#
# ----------------------------------------

# %%
for k in [3, 5, 10, 20]:
    mrr = mrr_at_k(evaluation_df, queries, index, tweet_sample, k)
    for i, q in enumerate(queries):
        print(f'The Reciprocal Rank@{k} for {q} is:')
        print(mrr[1][i])
        print()
    print(f"The Mean Reciprocal Rank@{k} is: {mrr[0]}")
    print()
    print("--"*20)
    print()
# Out:
# The Reciprocal Rank@3 for Q1 is:
# 1.0
#
# The Reciprocal Rank@3 for Q2 is:
# 1.0
#
# The Reciprocal Rank@3 for Q3 is:
# 1.0
#
# The Reciprocal Rank@3 for Q4 is:
# 1.0
#
# The Reciprocal Rank@3 for Q5 is:
# 1.0
#
# The Mean Reciprocal Rank@3 is: 1.0
#
# ----------------------------------------
#
# The Reciprocal Rank@5 for Q1 is:
# 1.0
#
# The Reciprocal Rank@5 for Q2 is:
# 1.0
#
# The Reciprocal Rank@5 for Q3 is:
# 1.0
#
# The Reciprocal Rank@5 for Q4 is:
# 1.0
#
# The Reciprocal Rank@5 for Q5 is:
# 1.0
#
# The Mean Reciprocal Rank@5 is: 1.0
#
# ----------------------------------------
#
# The Reciprocal Rank@10 for Q1 is:
# 1.0
#
# The Reciprocal Rank@10 for Q2 is:
# 1.0
#
# The Reciprocal Rank@10 for Q3 is:
# 1.0
#
# The Reciprocal Rank@10 for Q4 is:
# 1.0
#
# The Reciprocal Rank@10 for Q5 is:
# 1.0
#
# The Mean Reciprocal Rank@10 is: 1.0
#
# ----------------------------------------
#
# The Reciprocal Rank@20 for Q1 is:
# 1.0
#
# The Reciprocal Rank@20 for Q2 is:
# 1.0
#
# The Reciprocal Rank@20 for Q3 is:
# 1.0
#
# The Reciprocal Rank@20 for Q4 is:
# 1.0
#
# The Reciprocal Rank@20 for Q5 is:
# 1.0
#
# The Mean Reciprocal Rank@20 is: 1.0
#
# ----------------------------------------

# %%
for k in [3, 5, 10, 20]:
    mndcg = mndcg_at_k(evaluation_df, queries, index, tweet_sample, k)
    for i, q in enumerate(queries):
        print(f'The Normalized Discounted Cumulative Gain@{k} for {q} is:')
        print(mndcg[1][i])
        print()

    print(f"The Mean Normalized Discounted Cumulative Gain@{k} is: {mndcg[0]}")
    print()
    print("--"*20)
    print()
# Out:
# The Normalized Discounted Cumulative Gain@3 for Q1 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@3 for Q2 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@3 for Q3 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@3 for Q4 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@3 for Q5 is:
# 1.0
#
# The Mean Normalized Discounted Cumulative Gain@3 is: 1.0
#
# ----------------------------------------
#
# The Normalized Discounted Cumulative Gain@5 for Q1 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@5 for Q2 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@5 for Q3 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@5 for Q4 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@5 for Q5 is:
# 1.0
#
# The Mean Normalized Discounted Cumulative Gain@5 is: 1.0
#
# ----------------------------------------
#
# The Normalized Discounted Cumulative Gain@10 for Q1 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@10 for Q2 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@10 for Q3 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@10 for Q4 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@10 for Q5 is:
# 1.0
#
# The Mean Normalized Discounted Cumulative Gain@10 is: 1.0
#
# ----------------------------------------
#
# The Normalized Discounted Cumulative Gain@20 for Q1 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@20 for Q2 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@20 for Q3 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@20 for Q4 is:
# 1.0
#
# The Normalized Discounted Cumulative Gain@20 for Q5 is:
# 1.0
#
# The Mean Normalized Discounted Cumulative Gain@20 is: 1.0
#
# ----------------------------------------

# %% [markdown]
# ### Vector representation

# %%
# !pip install gensim
# !pip install scikit-learn
# !pip install matplotlib
# !pip install plotly
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.3)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (23.2)

# %%
import plotly.express as px
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE

texts = [" ".join(tweet['full_text_tokenized']) for tweet in tweets]
#Create instance of TfidfVectorizer
vectorizer = TfidfVectorizer(max_features=1000)
#Transfrom texts into a TF_IDF matrix
tfidf_matrix = vectorizer.fit_transform(texts)

#Create instance of TSNE
tsne = TSNE(n_components=2, random_state=0)
#Reduce data to 2D
X_tsne = tsne.fit_transform(tfidf_matrix.toarray())

import pandas as pd
#Create dataframe witht the reduced dimensions
df = pd.DataFrame(X_tsne, columns=["x", "y"])
#Add column of tokenized tweets
df['text'] = texts

fig = px.scatter(df, x='x', y='y', hover_data=['text'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9d22b0b1-dd09-46d7-a577-3c9cfb35ed2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d22b0b1-dd09-46d7-a577-3c9cfb35ed2f")) {                    Plotly.newPlot(                        "9d22b0b1-dd09-46d7-a577-3c9cfb35ed2f",                        [{"customdata":[["@melsimmonsfcdo wrong dictat putin fascist russia intend conquer much ukrainian land possibl #russiainvadesukrain #ukrainerussiawar"],["arm forc liber villag #drobyshev #lymansk urban territori commun #donetsk region#ukrainerussiawar #ukrainewar #ukrain #ukrainewillwin #ukrainianarmi #ukrainecounteroffens #ukrainewarnew #slavaukra\u00efni #standwithukrain https\u002f\u002ftco\u002fifg0rxdmbq"],["alert poland prep antiradi tablet nuclear threat #nato #putin #russia #russiainvadedukrain #ukrain #ukrainerussiawar"],["i\u2019m still wait googl map updat russia new annex territori it\u2019 take bit longer thought #putin #ukrainerussiawar"],["@emmanuelmacron probabl your right say anyway game #european citizen tire pay endless #ukrainerussiawar"],["estonia lithuania latvia fulli support welcom ukrain nato soon possibl lithuania minist foreign affair say #russia #russiainvadedukrain #ukrain #ukrainerussiawar"],["nato ukrain poke bear russia get mad bear russia wake smell unsanitari chemic biolab #putin #ukrain #ukrainewar #ukrainerussiawar"],["#ukrainerussiawar #ukrain #russia #osc condemn russia illeg annex ukrainian territori call russian feder withdraw forc across ukrain https\u002f\u002ftco\u002fhlveqljyel https\u002f\u002ftco\u002fkod7z6kvg"],["russia #putin #moscow #russia putin cheer crowd russia russia russia red yard moscow #russian #ukrainerussiawar https\u002f\u002ftco\u002fnhs63a768b"],["#standwithukrain #appeas #russia west #ukrainewar #ukrainerussiawar #ukrainerussianwar #ukrainewillwin #russianukrainianwar #russiaterroristst https\u002f\u002ftco\u002flx5akndvbg"],["don\u2019t recal peace\u002ftruc talk peopl thought russia win #ukrainerussiawar"],["#ukrain cannot obviou reason war countri join whilst war would also trigger end day #wwiii #ww3 #nuclearwar #ukrainewar #ukrainerussiawar #nato #europeanunion #new #breakingnew #break https\u002f\u002ftco\u002fbqrq91uix7"],["berlin ukrain brussel ukrain london ukrain stockholm ukrain pari ukrain europ ukrain like kyiv #ukrain ukrain ukrain continent threat let face https\u002f\u002ftco\u002farqwskprwd #warinukrain #ukrainewar #ukrainerussiawar https\u002f\u002ftco\u002foaaynndmdm https\u002f\u002ftco\u002fttsyk0eghx"],["#russia took 90 thousand kilomet #ukrain 15 percent area includ boundari #ukrainewar #ukrainerussianwar #ukrainerussiawar https\u002f\u002ftco\u002fz7zgyebggz"],["russian men flee turkey avoid putin\u2019 mobilis ukrain war @france24 #ukrain #ukrainewar #ukrainerussiawar #ukrainianarmi #ukrainian #ukraina #russia #russian #russiainvadedukrain https\u002f\u002ftco\u002fbbhbocqoft"],["russian consul vandal nyc putin declar annex vandal consul come russian presid putin declar illeg annex four occupi territori #ukrain #ukrainerussiawar watch video https\u002f\u002ftco\u002ff0hrid3uy https\u002f\u002ftco\u002feojnhxddw9"],["1\u00bd minut video ukrainian oper #lyman area septemb 2930 russian align sourc rybar #ukrainerussiawar #ukrainerussianwar #ukrainewar #zarichn #torsk #yampil #liman https\u002f\u002ftco\u002fvesxejmbvr"],["russian bomber capabl carri nuke detect near #finland bomber capabl carri cruis missil strateg nuclear weapon #ukraine#ukrainerussianwar #ukrainewar #ukrainerussiawar https\u002f\u002ftco\u002flxv4dgspfw"],["number peopl kill result rocket attack humanitarian convoy #zaporizhzhia increas 30 number injur also increas 88 includ 27 law enforc offic #ukrain #ukrainerussiawar  ...

# %%
from gensim.models import Word2Vec
import numpy as np
import plotly.express as px
import pandas as pd

#Create Word2Vec model
model = Word2Vec(sentences=[tweet['full_text_tokenized'] for tweet in tweets], vector_size=100, window=5, min_count=1, workers=4)

tweet_vectors = []
filtered_tweets = []

for tweet in tweets:
    words = [word for word in tweet['full_text_tokenized'] if word in model.wv.key_to_index]
    if words:
        tweet_vector = np.mean([model.wv[word] for word in words], axis=0)
        tweet_vectors.append(tweet_vector)
        filtered_tweets.append(tweet)

tweet_vectors_np = np.array(tweet_vectors)

tsne_model = TSNE(n_components=2, random_state=0)
reduced_data = tsne_model.fit_transform(tweet_vectors_np)

df = pd.DataFrame(reduced_data, columns=["x", "y"])
df['text'] = [" ".join(tweet['full_text_tokenized']) for tweet in filtered_tweets]

plot = px.scatter(df, x='x', y='y', hover_data=['text'])
plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d1294ed6-7fd4-48b2-a67f-3938a595f6a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d1294ed6-7fd4-48b2-a67f-3938a595f6a8")) {                    Plotly.newPlot(                        "d1294ed6-7fd4-48b2-a67f-3938a595f6a8",                        [{"customdata":[["@melsimmonsfcdo wrong dictat putin fascist russia intend conquer much ukrainian land possibl #russiainvadesukrain #ukrainerussiawar"],["arm forc liber villag #drobyshev #lymansk urban territori commun #donetsk region#ukrainerussiawar #ukrainewar #ukrain #ukrainewillwin #ukrainianarmi #ukrainecounteroffens #ukrainewarnew #slavaukra\u00efni #standwithukrain https\u002f\u002ftco\u002fifg0rxdmbq"],["alert poland prep antiradi tablet nuclear threat #nato #putin #russia #russiainvadedukrain #ukrain #ukrainerussiawar"],["i\u2019m still wait googl map updat russia new annex territori it\u2019 take bit longer thought #putin #ukrainerussiawar"],["@emmanuelmacron probabl your right say anyway game #european citizen tire pay endless #ukrainerussiawar"],["estonia lithuania latvia fulli support welcom ukrain nato soon possibl lithuania minist foreign affair say #russia #russiainvadedukrain #ukrain #ukrainerussiawar"],["nato ukrain poke bear russia get mad bear russia wake smell unsanitari chemic biolab #putin #ukrain #ukrainewar #ukrainerussiawar"],["#ukrainerussiawar #ukrain #russia #osc condemn russia illeg annex ukrainian territori call russian feder withdraw forc across ukrain https\u002f\u002ftco\u002fhlveqljyel https\u002f\u002ftco\u002fkod7z6kvg"],["russia #putin #moscow #russia putin cheer crowd russia russia russia red yard moscow #russian #ukrainerussiawar https\u002f\u002ftco\u002fnhs63a768b"],["#standwithukrain #appeas #russia west #ukrainewar #ukrainerussiawar #ukrainerussianwar #ukrainewillwin #russianukrainianwar #russiaterroristst https\u002f\u002ftco\u002flx5akndvbg"],["don\u2019t recal peace\u002ftruc talk peopl thought russia win #ukrainerussiawar"],["#ukrain cannot obviou reason war countri join whilst war would also trigger end day #wwiii #ww3 #nuclearwar #ukrainewar #ukrainerussiawar #nato #europeanunion #new #breakingnew #break https\u002f\u002ftco\u002fbqrq91uix7"],["berlin ukrain brussel ukrain london ukrain stockholm ukrain pari ukrain europ ukrain like kyiv #ukrain ukrain ukrain continent threat let face https\u002f\u002ftco\u002farqwskprwd #warinukrain #ukrainewar #ukrainerussiawar https\u002f\u002ftco\u002foaaynndmdm https\u002f\u002ftco\u002fttsyk0eghx"],["#russia took 90 thousand kilomet #ukrain 15 percent area includ boundari #ukrainewar #ukrainerussianwar #ukrainerussiawar https\u002f\u002ftco\u002fz7zgyebggz"],["russian men flee turkey avoid putin\u2019 mobilis ukrain war @france24 #ukrain #ukrainewar #ukrainerussiawar #ukrainianarmi #ukrainian #ukraina #russia #russian #russiainvadedukrain https\u002f\u002ftco\u002fbbhbocqoft"],["russian consul vandal nyc putin declar annex vandal consul come russian presid putin declar illeg annex four occupi territori #ukrain #ukrainerussiawar watch video https\u002f\u002ftco\u002ff0hrid3uy https\u002f\u002ftco\u002feojnhxddw9"],["1\u00bd minut video ukrainian oper #lyman area septemb 2930 russian align sourc rybar #ukrainerussiawar #ukrainerussianwar #ukrainewar #zarichn #torsk #yampil #liman https\u002f\u002ftco\u002fvesxejmbvr"],["russian bomber capabl carri nuke detect near #finland bomber capabl carri cruis missil strateg nuclear weapon #ukraine#ukrainerussianwar #ukrainewar #ukrainerussiawar https\u002f\u002ftco\u002flxv4dgspfw"],["number peopl kill result rocket attack humanitarian convoy #zaporizhzhia increas 30 number injur also increas 88 includ 27 law enforc offic #ukrain #ukrainerussiawar  ...
